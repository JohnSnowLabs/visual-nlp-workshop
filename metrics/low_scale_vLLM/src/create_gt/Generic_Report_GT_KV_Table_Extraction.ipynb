# %% [markdown]
# # Create key-value groundtruth from custom Genetic Reports 0.1 dataset

# %% [markdown]
# ## Setup

# %%
import json
import os

def process_json_file(input_filepath, output_filepath):
    with open(input_filepath, 'r', encoding='utf-8') as file:
        data = json.load(file)

    questions = {}
    answers = {}

    # First pass: collect questions and answers
    for item in data['form']:
        if item['label'] == 'question':
            questions[item['id']] = item['text']
        elif item['label'] == 'answer':
            answers[item['id']] = item['text']

    # Second pass: link questions and answers
    results = {}
    for item in data['form']:
        if item['label'] == 'question':
            question_id = item['id']
            for link in item['linking']:
                answer_id = link[1]
                if answer_id in answers:
                    question_text = questions.get(question_id, "")
                    answer_text = answers.get(answer_id, "")
                    if question_text in results:
                        results[question_text].append(answer_text)
                    else:
                        results[question_text] = [answer_text]

    # Write the output JSON
    output_data = {}
    for question, answer_list in results.items():
        output_data[question] = answer_list

    with open(output_filepath, 'w', encoding='utf-8') as file:
        json.dump(output_data, file, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Load dataset
#
# Upload result from cloud provider algorithm in zip format

# %%
# !unzip spark_generic_reports_v6.zip
# Out:
# Archive:  spark_generic_reports_v6.zip
#    creating: spark_generic_reports_v6/
#    creating: spark_generic_reports_v6/annotations/
#   inflating: spark_generic_reports_v6/annotations/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json
#   inflating: spark_generic_reports_v6/annotations/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json
#   inflating: spark_generic_reports_v6/annotations/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json
#   inflating: spark_generic_reports_v6/annotations/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_0.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_1.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_2.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_4.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_5.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_6.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_7.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_8.json
#   inflating: spark_generic_reports_v6/annotations/oncoextra-tnbc-ntrk-wm-sample-report_9.json
#   inflating: spark_generic_reports_v6/annotations/Sample-NGS-Thyroid-MTC-report_changed_0.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_0.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_1.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_10.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_2.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_3.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_4.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_5.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_6.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_7.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_8.json
#   inflating: spark_generic_reports_v6/annotations/Tempus-Onco_Clinical-Report-Sample_9.json
#    creating: spark_generic_reports_v6/images/
#   inflating: spark_generic_reports_v6/images/.DS_Store
#   inflating: spark_generic_reports_v6/images/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.png
#   inflating: spark_generic_reports_v6/images/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.png
#   inflating: spark_generic_reports_v6/images/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.png
#   inflating: spark_generic_reports_v6/images/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_0.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_1.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_2.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_4.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_5.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_6.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_7.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_8.png
#   inflating: spark_generic_reports_v6/images/oncoextra-tnbc-ntrk-wm-sample-report_9.png
#   inflating: spark_generic_reports_v6/images/Sample-NGS-Thyroid-MTC-report_changed_0.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_0.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_1.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_10.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_2.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_3.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_4.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_5.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_6.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_7.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_8.png
#   inflating: spark_generic_reports_v6/images/Tempus-Onco_Clinical-Report-Sample_9.png

# %% [markdown]
# ## Execution

# %%
# Define paths
funsd_path = r'spark_generic_reports_v6/annotations'
output_path = r'spark_generic_reports_v6_gt'

os.makedirs(output_path, exist_ok=True)

# %%
# Process all JSON files in the input directory
for filename in os.listdir(funsd_path):
    if filename.endswith('.json'):
        input_filepath = os.path.join(funsd_path, filename)
        output_filepath = os.path.join(output_path, filename)
        process_json_file(input_filepath, output_filepath)

print("Processing completed.")
# Out:
# Processing completed.

# %% [markdown]
# ## Download result

# %%
# !zip -r spark_generic_reports_v6_gt.zip spark_generic_reports_v6_gt
# Out:
#   adding: spark_generic_reports_v6_gt/ (stored 0%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_4.json (deflated 58%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_9.json (deflated 51%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json (deflated 41%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_6.json (deflated 55%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_4.json (deflated 52%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_1.json (deflated 55%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json (deflated 54%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json (deflated 44%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json (deflated 37%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json (deflated 43%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json (deflated 40%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json (deflated 61%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json (deflated 66%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json (deflated 51%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_10.json (deflated 56%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json (deflated 50%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json (deflated 59%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json (deflated 64%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json (deflated 41%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json (deflated 38%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json (deflated 54%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_6.json (deflated 51%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json (deflated 63%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json (deflated 55%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json (deflated 73%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json (deflated 64%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_2.json (deflated 57%)
#   adding: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json (deflated 71%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_7.json (deflated 79%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json (deflated 65%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json (deflated 38%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json (deflated 37%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json (deflated 52%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json (deflated 59%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_5.json (deflated 55%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json (deflated 57%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_0.json (deflated 59%)
#   adding: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json (deflated 64%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.json (deflated 40%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json (deflated 60%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json (deflated 54%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json (deflated 61%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json (deflated 44%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json (deflated 72%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json (deflated 72%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.json (deflated 66%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_0.json (deflated 64%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_3.json (deflated 55%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json (deflated 64%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json (deflated 72%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_2.json (deflated 52%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json (deflated 44%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json (deflated 63%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_8.json (deflated 52%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_7.json (deflated 54%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json (deflated 64%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_5.json (deflated 53%)
#   adding: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_1.json (deflated 59%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json (deflated 65%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json (deflated 49%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json (deflated 73%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json (deflated 61%)
#   adding: spark_generic_reports_v6_gt/Sample-NGS-Thyroid-MTC-report_changed_0.json (deflated 60%)
#   adding: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json (deflated 49%)
#   adding: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json (deflated 70%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_8.json (deflated 65%)
#   adding: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_9.json (deflated 57%)

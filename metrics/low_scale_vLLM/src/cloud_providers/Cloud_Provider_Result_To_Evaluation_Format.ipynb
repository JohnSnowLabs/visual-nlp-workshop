# %% [markdown]
# # GeoLayoutLM to evaluation format

# %% [markdown]
# ## Setup

# %%
import os
import re
import shutil

# %%
# Function to copy files from "result..." directories to the destination directory
def copy_result_files(base_directory, destination_directory):
    # Walk through all subdirectories and files in the base directory
    for root, dirs, files in os.walk(base_directory):
        # Check if the current directory name contains "result"
        if 'result' in os.path.basename(root):
            for file in files:
                # Define the full file path
                file_path = os.path.join(root, file)
                # Define the destination file path
                destination_file_path = os.path.join(destination_directory, file)
                # Copy the file to the destination directory
                shutil.copy(file_path, destination_file_path)
                print(f"Copied: {file_path} to {destination_file_path}")

# %%
# Function to rename files and save them in a new directory
def rename_files(directory_path, new_directory_path):
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            print(filename)
            # Match the pattern and capture groups
            filename_new = filename.replace("_json_result", "")
            match = re.match(r'(.*_)(pdf_)(\d+)(\.json)', filename_new)
            if match:
                print(match)
                base_name = match.group(1)
                number = int(match.group(3)) - 1
                new_filename = f"{base_name}{number}.json"

                # Get full paths
                old_file = os.path.join(directory_path, filename)
                new_file = os.path.join(new_directory_path, new_filename)

                # Copy the file to the new location with the new name
                shutil.copy(old_file, new_file)
                print(f"Copied and renamed: {filename} to {new_filename}")

# %% [markdown]
# ## Load dataset
#
# Upload result from cloud provider algorithm in zip format

# %%
# !unzip result_amazon_with_tables.zip
# Out:
# Archive:  result_amazon_with_tables.zip
#    creating: result_amazon_with_tables/
#   inflating: result_amazon_with_tables/.DS_Store
#   inflating: result_amazon_with_tables/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_json_result.json
#  extracting: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_json_result.json
#  extracting: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_json_result.json
#  extracting: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_json_result.json
#  extracting: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_json_result.json
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_table_result.csv
#   inflating: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_json_result.json
#  extracting: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_10_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_10_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_11_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_11_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_12_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_12_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_13_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_13_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_14_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_14_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_15_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_15_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_16_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_16_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_17_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_17_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_18_json_result.json
#  extracting: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_18_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_19_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_19_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_20_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_20_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_21_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_21_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_22_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_22_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_23_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_23_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_2_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_2_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_3_json_result.json
#  extracting: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_3_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_4_json_result.json
#  extracting: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_4_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_5_json_result.json
#  extracting: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_5_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_6_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_6_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_7_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_7_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_8_json_result.json
#  extracting: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_8_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_9_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_9_table_result.csv
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) changed_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/F1CDx Sample Report (Lung) changed_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_table_result.csv
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_json_result.json
#   inflating: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_10_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_10_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_11_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_11_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_12_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_12_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_13_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_13_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_14_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_14_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_15_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_15_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_16_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_16_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_17_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_17_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_18_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_18_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_19_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_19_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_20_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_20_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_21_json_result.json
#  extracting: result_amazon_with_tables/Positive-Report_pdf_21_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_22_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_22_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_23_json_result.json
#  extracting: result_amazon_with_tables/Positive-Report_pdf_23_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_2_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_2_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_3_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_3_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_4_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_4_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_5_json_result.json
#  extracting: result_amazon_with_tables/Positive-Report_pdf_5_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_6_json_result.json
#  extracting: result_amazon_with_tables/Positive-Report_pdf_6_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_7_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_7_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_8_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_8_table_result.csv
#   inflating: result_amazon_with_tables/Positive-Report_pdf_9_json_result.json
#   inflating: result_amazon_with_tables/Positive-Report_pdf_9_table_result.csv
#   inflating: result_amazon_with_tables/Sample-NGS-Thyroid-MTC-report_changed_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/Sample-NGS-Thyroid-MTC-report_changed_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_10_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_10_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_11_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_11_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_1_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_1_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_2_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_2_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_3_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_3_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_4_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_4_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_5_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_5_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_6_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_6_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_7_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_7_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_8_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_8_table_result.csv
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_9_json_result.json
#   inflating: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_9_table_result.csv

# %% [markdown]
# ## Execution

# %%
base_directory = r'result_amazon_with_tables' # Path to cloud provider results
destination_directory = r'result_amazon_with_tables_result' # Define the destination directory where the files will be copied
new_directory_path = destination_directory + '_rename' # Define the path to the new directory for renamed files

os.makedirs(destination_directory, exist_ok=True)
os.makedirs(new_directory_path, exist_ok=True)

# %%
# Call the function to copy the files
copy_result_files(base_directory, destination_directory)
print("1st Step completed.")
# Out:
# Copied: result_amazon_with_tables/Positive-Report_pdf_8_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_8_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_json_result.json
# Copied: result_amazon_with_tables/.DS_Store to result_amazon_with_tables_result/.DS_Store
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_4_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_4_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_9_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_9_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_10_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_10_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_3_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_3_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_17_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_17_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_15_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_15_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_8_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_8_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_23_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_23_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_9_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_9_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_14_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_14_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_1_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_18_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_18_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_3_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_3_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_4_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_4_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_8_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_8_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_6_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_6_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_22_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_22_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_1_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_1_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_5_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_5_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_7_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_7_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_19_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_19_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_2_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_2_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_9_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_9_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_1_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_1_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_3_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_3_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_19_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_19_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_6_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_6_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_20_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_20_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_1_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_20_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_20_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_23_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_23_table_result.csv
# Copied: result_amazon_with_tables/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_table_result.csv to result_amazon_with_tables_result/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_23_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_23_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_10_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_10_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_12_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_12_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_16_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_16_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_6_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_6_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_8_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_8_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_15_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_15_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_6_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_6_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_13_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_13_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_19_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_19_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_10_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_10_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_5_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_5_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_7_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_7_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_5_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_5_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_2_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_2_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_12_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_12_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_5_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_5_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_7_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_7_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_8_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_8_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_6_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_6_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_14_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_14_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_10_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_10_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_1_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_1_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_7_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_7_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_18_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_18_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_17_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_17_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_11_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_11_json_result.json
# Copied: result_amazon_with_tables/Sample-NGS-Thyroid-MTC-report_changed_pdf_1_table_result.csv to result_amazon_with_tables_result/Sample-NGS-Thyroid-MTC-report_changed_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_16_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_16_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_18_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_18_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_3_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_3_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_11_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_11_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_22_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_22_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_11_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_11_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_21_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_21_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_20_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_20_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_14_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_14_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_1_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_11_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_11_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_7_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_7_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_15_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_15_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_3_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_3_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_4_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_4_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_4_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_4_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_11_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_11_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_4_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_4_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_22_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_22_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_23_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_23_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_10_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_10_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_14_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_14_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_3_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_3_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_13_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_13_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_18_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_18_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_5_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_5_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_16_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_16_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_8_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_8_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_16_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_16_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) changed_pdf_1_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) changed_pdf_1_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_21_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_21_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_9_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_9_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_2_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_2_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_10_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_10_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_15_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_15_table_result.csv
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_table_result.csv to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_table_result.csv
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_2_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_2_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_9_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_9_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_6_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_6_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_9_table_result.csv to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_9_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_13_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_13_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_5_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_5_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_7_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_7_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) changed_pdf_1_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) changed_pdf_1_json_result.json
# Copied: result_amazon_with_tables/oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_json_result.json to result_amazon_with_tables_result/oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_17_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_17_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_13_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_13_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_12_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_12_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_21_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_21_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_17_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_17_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_json_result.json to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_json_result.json
# Copied: result_amazon_with_tables/Sample-NGS-Thyroid-MTC-report_changed_pdf_1_json_result.json to result_amazon_with_tables_result/Sample-NGS-Thyroid-MTC-report_changed_pdf_1_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_2_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_2_json_result.json
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_table_result.csv
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_21_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_21_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_2_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_2_json_result.json
# Copied: result_amazon_with_tables/Positive-Report_pdf_22_json_result.json to result_amazon_with_tables_result/Positive-Report_pdf_22_json_result.json
# Copied: result_amazon_with_tables/Tempus-Onco_Clinical-Report-Sample_pdf_4_json_result.json to result_amazon_with_tables_result/Tempus-Onco_Clinical-Report-Sample_pdf_4_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_20_json_result.json to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_20_json_result.json
# Copied: result_amazon_with_tables/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_json_result.json to result_amazon_with_tables_result/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_json_result.json
# Copied: result_amazon_with_tables/F1CDx Sample Report (Lung) (copy)_pdf_12_table_result.csv to result_amazon_with_tables_result/F1CDx Sample Report (Lung) (copy)_pdf_12_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_11_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_11_table_result.csv
# Copied: result_amazon_with_tables/Positive-Report_pdf_19_table_result.csv to result_amazon_with_tables_result/Positive-Report_pdf_19_table_result.csv
# Copied: result_amazon_with_tables/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_table_result.csv to result_amazon_with_tables_result/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_table_result.csv
# 1st Step completed.

# %%
# Call the function to rename files and save them in the new directory
rename_files(destination_directory, new_directory_path)
print("2nd step completed: Copying and renaming.")
# Out:
# Positive-Report_pdf_8_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_8.json'>
# Copied and renamed: Positive-Report_pdf_8_json_result.json to Positive-Report_7.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_4_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json
# Tempus-Onco_Clinical-Report-Sample_pdf_9_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_9.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_9_json_result.json to Tempus-Onco_Clinical-Report-Sample_8.json
# Positive-Report_pdf_10_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_10.json'>
# Copied and renamed: Positive-Report_pdf_10_json_result.json to Positive-Report_9.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_23_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_8_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_2.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_2_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_1.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_7.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_7_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_6.json
# Positive-Report_pdf_23_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_23.json'>
# Copied and renamed: Positive-Report_pdf_23_json_result.json to Positive-Report_22.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_6_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json
# Positive-Report_pdf_14_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_14.json'>
# Copied and renamed: Positive-Report_pdf_14_json_result.json to Positive-Report_13.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_4.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_4_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_3.json
# Positive-Report_pdf_18_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_18.json'>
# Copied and renamed: Positive-Report_pdf_18_json_result.json to Positive-Report_17.json
# Tempus-Onco_Clinical-Report-Sample_pdf_3_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_3.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_3_json_result.json to Tempus-Onco_Clinical-Report-Sample_2.json
# F1CDx Sample Report (Lung) (copy)_pdf_8_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_8.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_8_json_result.json to F1CDx Sample Report (Lung) (copy)_7.json
# F1CDx Sample Report (Lung) (copy)_pdf_22_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_22.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_22_json_result.json to F1CDx Sample Report (Lung) (copy)_21.json
# Positive-Report_pdf_1_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_1.json'>
# Copied and renamed: Positive-Report_pdf_1_json_result.json to Positive-Report_0.json
# Tempus-Onco_Clinical-Report-Sample_pdf_7_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_7.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_7_json_result.json to Tempus-Onco_Clinical-Report-Sample_6.json
# Positive-Report_pdf_19_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_19.json'>
# Copied and renamed: Positive-Report_pdf_19_json_result.json to Positive-Report_18.json
# F1CDx Sample Report (Lung) (copy)_pdf_2_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_2.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_2_json_result.json to F1CDx Sample Report (Lung) (copy)_1.json
# Positive-Report_pdf_9_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_9.json'>
# Copied and renamed: Positive-Report_pdf_9_json_result.json to Positive-Report_8.json
# F1CDx Sample Report (Lung) (copy)_pdf_1_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_1.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_1_json_result.json to F1CDx Sample Report (Lung) (copy)_0.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_8.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_8_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_7.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_14_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_1_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_0.json
# Positive-Report_pdf_12_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_12.json'>
# Copied and renamed: Positive-Report_pdf_12_json_result.json to Positive-Report_11.json
# Positive-Report_pdf_6_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_6.json'>
# Copied and renamed: Positive-Report_pdf_6_json_result.json to Positive-Report_5.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_3_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_2.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_12_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_3.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_3_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_2.json
# Positive-Report_pdf_15_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_15.json'>
# Copied and renamed: Positive-Report_pdf_15_json_result.json to Positive-Report_14.json
# Tempus-Onco_Clinical-Report-Sample_pdf_6_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_6.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_6_json_result.json to Tempus-Onco_Clinical-Report-Sample_5.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_19_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json
# F1CDx Sample Report (Lung) (copy)_pdf_13_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_13.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_13_json_result.json to F1CDx Sample Report (Lung) (copy)_12.json
# F1CDx Sample Report (Lung) (copy)_pdf_19_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_19.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_19_json_result.json to F1CDx Sample Report (Lung) (copy)_18.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_16_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_6.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_6_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_5.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_9_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json
# Tempus-Onco_Clinical-Report-Sample_pdf_5_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_5.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_5_json_result.json to Tempus-Onco_Clinical-Report-Sample_4.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_9.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_9_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_8.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_json_result.json
# <re.Match object; span=(0, 48), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_10.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_10_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_9.json
# F1CDx Sample Report (Lung) (copy)_pdf_12_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_12.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_12_json_result.json to F1CDx Sample Report (Lung) (copy)_11.json
# Positive-Report_pdf_7_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_7.json'>
# Copied and renamed: Positive-Report_pdf_7_json_result.json to Positive-Report_6.json
# F1CDx Sample Report (Lung) (copy)_pdf_10_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_10.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_10_json_result.json to F1CDx Sample Report (Lung) (copy)_9.json
# Tempus-Onco_Clinical-Report-Sample_pdf_1_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_1.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_1_json_result.json to Tempus-Onco_Clinical-Report-Sample_0.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_2_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_1.json
# Tempus-Onco_Clinical-Report-Sample_pdf_11_json_result.json
# <re.Match object; span=(0, 46), match='Tempus-Onco_Clinical-Report-Sample_pdf_11.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_11_json_result.json to Tempus-Onco_Clinical-Report-Sample_10.json
# F1CDx Sample Report (Lung) (copy)_pdf_16_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_16.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_16_json_result.json to F1CDx Sample Report (Lung) (copy)_15.json
# Positive-Report_pdf_3_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_3.json'>
# Copied and renamed: Positive-Report_pdf_3_json_result.json to Positive-Report_2.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_7_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json
# Positive-Report_pdf_20_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_20.json'>
# Copied and renamed: Positive-Report_pdf_20_json_result.json to Positive-Report_19.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_15_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_22_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_17_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json
# F1CDx Sample Report (Lung) (copy)_pdf_11_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_11.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_11_json_result.json to F1CDx Sample Report (Lung) (copy)_10.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_21_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json
# F1CDx Sample Report (Lung) (copy)_pdf_15_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_15.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_15_json_result.json to F1CDx Sample Report (Lung) (copy)_14.json
# F1CDx Sample Report (Lung) (copy)_pdf_3_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_3.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_3_json_result.json to F1CDx Sample Report (Lung) (copy)_2.json
# F1CDx Sample Report (Lung) (copy)_pdf_4_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_4.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_4_json_result.json to F1CDx Sample Report (Lung) (copy)_3.json
# Positive-Report_pdf_11_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_11.json'>
# Copied and renamed: Positive-Report_pdf_11_json_result.json to Positive-Report_10.json
# Positive-Report_pdf_4_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_4.json'>
# Copied and renamed: Positive-Report_pdf_4_json_result.json to Positive-Report_3.json
# F1CDx Sample Report (Lung) (copy)_pdf_23_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_23.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_23_json_result.json to F1CDx Sample Report (Lung) (copy)_22.json
# F1CDx Sample Report (Lung) (copy)_pdf_14_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_14.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_14_json_result.json to F1CDx Sample Report (Lung) (copy)_13.json
# F1CDx Sample Report (Lung) (copy)_pdf_18_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_18.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_18_json_result.json to F1CDx Sample Report (Lung) (copy)_17.json
# Positive-Report_pdf_5_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_5.json'>
# Copied and renamed: Positive-Report_pdf_5_json_result.json to Positive-Report_4.json
# Tempus-Onco_Clinical-Report-Sample_pdf_8_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_8.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_8_json_result.json to Tempus-Onco_Clinical-Report-Sample_7.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_13_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json
# Positive-Report_pdf_16_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_16.json'>
# Copied and renamed: Positive-Report_pdf_16_json_result.json to Positive-Report_15.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_20_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_1.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_1_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_0.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_json_result.json
# <re.Match object; span=(0, 58), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_5_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json
# F1CDx Sample Report (Lung) (copy)_pdf_9_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_9.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_9_json_result.json to F1CDx Sample Report (Lung) (copy)_8.json
# Tempus-Onco_Clinical-Report-Sample_pdf_10_json_result.json
# <re.Match object; span=(0, 46), match='Tempus-Onco_Clinical-Report-Sample_pdf_10.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_10_json_result.json to Tempus-Onco_Clinical-Report-Sample_9.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_18_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json
# F1CDx Sample Report (Lung) (copy)_pdf_6_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_6.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_6_json_result.json to F1CDx Sample Report (Lung) (copy)_5.json
# F1CDx Sample Report (Lung) (copy)_pdf_5_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_5.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_5_json_result.json to F1CDx Sample Report (Lung) (copy)_4.json
# F1CDx Sample Report (Lung) (copy)_pdf_7_json_result.json
# <re.Match object; span=(0, 44), match='F1CDx Sample Report (Lung) (copy)_pdf_7.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_7_json_result.json to F1CDx Sample Report (Lung) (copy)_6.json
# F1CDx Sample Report (Lung) changed_pdf_1_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) changed_pdf_1.json'>
# Copied and renamed: F1CDx Sample Report (Lung) changed_pdf_1_json_result.json to F1CDx Sample Report (Lung) changed_0.json
# oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_json_result.json
# <re.Match object; span=(0, 47), match='oncoextra-tnbc-ntrk-wm-sample-report_pdf_5.json'>
# Copied and renamed: oncoextra-tnbc-ntrk-wm-sample-report_pdf_5_json_result.json to oncoextra-tnbc-ntrk-wm-sample-report_4.json
# Positive-Report_pdf_17_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_17.json'>
# Copied and renamed: Positive-Report_pdf_17_json_result.json to Positive-Report_16.json
# Positive-Report_pdf_13_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_13.json'>
# Copied and renamed: Positive-Report_pdf_13_json_result.json to Positive-Report_12.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_11_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json
# Positive-Report_pdf_21_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_21.json'>
# Copied and renamed: Positive-Report_pdf_21_json_result.json to Positive-Report_20.json
# F1CDx Sample Report (Lung) (copy)_pdf_17_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_17.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_17_json_result.json to F1CDx Sample Report (Lung) (copy)_16.json
# CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_json_result.json
# <re.Match object; span=(0, 59), match='CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_p>
# Copied and renamed: CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_pdf_10_json_result.json to CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json
# Sample-NGS-Thyroid-MTC-report_changed_pdf_1_json_result.json
# <re.Match object; span=(0, 48), match='Sample-NGS-Thyroid-MTC-report_changed_pdf_1.json'>
# Copied and renamed: Sample-NGS-Thyroid-MTC-report_changed_pdf_1_json_result.json to Sample-NGS-Thyroid-MTC-report_changed_0.json
# Positive-Report_pdf_2_json_result.json
# <re.Match object; span=(0, 26), match='Positive-Report_pdf_2.json'>
# Copied and renamed: Positive-Report_pdf_2_json_result.json to Positive-Report_1.json
# F1CDx Sample Report (Lung) (copy)_pdf_21_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_21.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_21_json_result.json to F1CDx Sample Report (Lung) (copy)_20.json
# Tempus-Onco_Clinical-Report-Sample_pdf_2_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_2.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_2_json_result.json to Tempus-Onco_Clinical-Report-Sample_1.json
# Positive-Report_pdf_22_json_result.json
# <re.Match object; span=(0, 27), match='Positive-Report_pdf_22.json'>
# Copied and renamed: Positive-Report_pdf_22_json_result.json to Positive-Report_21.json
# Tempus-Onco_Clinical-Report-Sample_pdf_4_json_result.json
# <re.Match object; span=(0, 45), match='Tempus-Onco_Clinical-Report-Sample_pdf_4.json'>
# Copied and renamed: Tempus-Onco_Clinical-Report-Sample_pdf_4_json_result.json to Tempus-Onco_Clinical-Report-Sample_3.json
# F1CDx Sample Report (Lung) (copy)_pdf_20_json_result.json
# <re.Match object; span=(0, 45), match='F1CDx Sample Report (Lung) (copy)_pdf_20.json'>
# Copied and renamed: F1CDx Sample Report (Lung) (copy)_pdf_20_json_result.json to F1CDx Sample Report (Lung) (copy)_19.json
# Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_json_result.json
# <re.Match object; span=(0, 72), match='Caris-Molecular-Intelligence_MI-Profile_Breast_NO>
# Copied and renamed: Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_pdf_1_json_result.json to Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json
# 2nd step completed: Copying and renaming.

# %% [markdown]
# ## Download result

# %%
# !zip -r result_amazon_with_tables_result_rename.zip result_amazon_with_tables_result_rename
# Out:
#   adding: result_amazon_with_tables_result_rename/ (stored 0%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_2.json (deflated 62%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_3.json (deflated 59%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_2.json (deflated 40%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json (deflated 48%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_8.json (deflated 59%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json (deflated 36%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_2.json (deflated 56%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_18.json (deflated 48%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_15.json (deflated 72%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json (deflated 38%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_5.json (deflated 59%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) changed_0.json (deflated 56%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_1.json (deflated 58%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_5.json (deflated 49%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_3.json (deflated 40%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_4.json (deflated 51%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_6.json (deflated 43%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_11.json (deflated 67%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_9.json (deflated 63%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_6.json (deflated 61%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_11.json (deflated 52%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_13.json (deflated 51%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json (deflated 57%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_7.json (deflated 50%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json (deflated 62%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_2.json (deflated 52%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_5.json (deflated 51%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_0.json (deflated 60%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_8.json (deflated 49%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json (deflated 54%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_6.json (deflated 70%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_16.json (deflated 61%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json (deflated 60%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_1.json (deflated 42%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json (deflated 45%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_10.json (deflated 64%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_18.json (deflated 69%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_1.json (deflated 59%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_12.json (deflated 70%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_8.json (deflated 72%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_0.json (deflated 52%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_19.json (deflated 61%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json (deflated 23%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json (deflated 26%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_0.json (deflated 57%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_0.json (deflated 58%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_10.json (deflated 68%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json (deflated 54%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_20.json (deflated 32%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json (deflated 63%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json (deflated 52%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_13.json (deflated 68%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_7.json (deflated 68%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_17.json (deflated 68%)
#   adding: result_amazon_with_tables_result_rename/Sample-NGS-Thyroid-MTC-report_changed_0.json (deflated 55%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_4.json (deflated 43%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_15.json (deflated 47%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_14.json (deflated 70%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_3.json (deflated 45%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_17.json (deflated 50%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json (deflated 63%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_6.json (deflated 53%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json (deflated 32%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_21.json (deflated 53%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_10.json (deflated 45%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_9.json (deflated 53%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_22.json (deflated 44%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json (deflated 60%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_4.json (deflated 46%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_5.json (deflated 27%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_20.json (deflated 58%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_3.json (deflated 44%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_1.json (deflated 52%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_0.json (deflated 50%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_21.json (deflated 40%)
#   adding: result_amazon_with_tables_result_rename/oncoextra-tnbc-ntrk-wm-sample-report_7.json (deflated 68%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_14.json (deflated 63%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_22.json (deflated 58%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json (deflated 50%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_9.json (deflated 71%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_8.json (deflated 61%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_4.json (deflated 38%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_2.json (deflated 48%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json (deflated 57%)
#   adding: result_amazon_with_tables_result_rename/Positive-Report_16.json (deflated 71%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_7.json (deflated 41%)
#   adding: result_amazon_with_tables_result_rename/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json (deflated 56%)
#   adding: result_amazon_with_tables_result_rename/Tempus-Onco_Clinical-Report-Sample_9.json (deflated 45%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json (deflated 42%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json (deflated 66%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_12.json (deflated 64%)
#   adding: result_amazon_with_tables_result_rename/F1CDx Sample Report (Lung) (copy)_19.json (deflated 62%)
#   adding: result_amazon_with_tables_result_rename/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_1.json (deflated 64%)

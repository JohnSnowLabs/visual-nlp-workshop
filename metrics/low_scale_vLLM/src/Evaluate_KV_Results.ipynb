# %% [markdown]
# # JSON based Key Value metrics

# %% [markdown]
# ## Setup

# %%
# !python3 -m pip install levenshtein
# Out:
# Collecting levenshtein
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from levenshtein)
#   Downloading rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 6.0 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 43.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.25.1 rapidfuzz-3.9.6

# %% [markdown]
# ## Upload data: the results to be evaluate and the gt

# %%
# !unzip spark_generic_reports_v6_gt.zip
# !unzip vLLM_v3_CustomReports01_fixoutput.zip
# Out:
# Archive:  spark_generic_reports_v6_gt.zip
#    creating: spark_generic_reports_v6_gt/
#   inflating: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json
#   inflating: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json
#   inflating: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json
#   inflating: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_0.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_1.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_2.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_4.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_5.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_6.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_7.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_8.json
#   inflating: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_9.json
#   inflating: spark_generic_reports_v6_gt/Sample-NGS-Thyroid-MTC-report_changed_0.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_0.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_1.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_10.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_2.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_3.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_4.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_5.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_6.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_7.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_8.json
#   inflating: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_9.json
# Archive:  vLLM_v3_CustomReports01_fixoutput.zip
#    creating: vLLM_v3_CustomReports01_fixoutput/
#   inflating: vLLM_v3_CustomReports01_fixoutput/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_0.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_1.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_2.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_4.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_5.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_6.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_7.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_8.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_9.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Sample-NGS-Thyroid-MTC-report_changed_0.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_0.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_1.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_10.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_2.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_3.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_4.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_5.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_6.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_7.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_8.json
#   inflating: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_9.json

# %% [markdown]
# ## Processing JSON functions to Eval

# %%
import os
import json
import Levenshtein as lev
from Levenshtein import distance


# Función para convertir las claves del diccionario a minúsculas
def convert_keys_to_lowercase(obj):
    if isinstance(obj, dict):
        return {k.lower(): convert_keys_to_lowercase(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [convert_keys_to_lowercase(item) for item in obj]
    else:
        return obj


# let's define the metric here, we can modularize later
def score(sample, gold, taos=[.5]):
    """
    Scores a 'sample' JSON string against a 'gold' reference.

    :param sample: JSON string to be scored.
    :param gold: Reference 'gold' JSON string.
    :param taos: Optional threshold(s) for the scoring metric (default is [0.5]).
                 The lower the threshold, the most permissive the metric.
    :return: an array of scores for each tao value.
    """
    sample = json.loads(sample)
    gold = json.loads(gold)

    # stringify all the values
    sample = {k: str(v) for k,v in sample.items()}
    gold = {k: str(v) for k,v in gold.items()}

    # True Positives: take the output of provider and match it against ground truth.
    # We can penalize on the OCR quality like {Name: Alberto} vs. {Name: Albero}, we
    # will count 0.8 instead of 1, etc. The same for the key.
    tp = []
    # False Positives: the provider returns a key that is not in gold truth,
    # like "city: New York", and that pair is not in gold standard.
    fp = []
    for sample_key in sample:
        # is this key in the gold ref?
        if sample_key in gold.keys():
            goldv = gold[sample_key]
            norm_dist = distance(sample[sample_key], goldv) / max(len(sample_key), len(goldv))
            # apply the tao threshold on the distance
            tp.append(1 - norm_dist if norm_dist < taos[0] else 0.0)
            gold.pop(sample_key)
        # if not then we soft match on the keys
        else:
            # let's collect candidate keys
            cand_keys = [(k, distance(sample_key, k)/max(len(k), len(sample_key))) for k in gold.keys()]
            cand_keys = [(k, 1 - nd if nd < taos[0] else 0.0) for k, nd in cand_keys]
            cand_keys = [(k, v) for k,v in cand_keys if v > 0.0]
            # if we found candidate keys we move forward otherwise we don't count a tp
            if cand_keys:
                (key, kscore) = max(cand_keys, key=lambda x: x[1])

                vdist = distance(str(gold[key]), str(sample[sample_key])) / max(len(gold[key]), len(sample[sample_key]))
                vscore = 1 - vdist if vdist < taos[0] else 0.0

                # if we meet the 2 thresholds we count the average of k/v scores
                if vscore > 0.0:
                    tp.append((kscore + vscore) / 2)
                    # penalize the OCR mismatch
                    fp.append(1 - (kscore + vscore) / 2)
                    gold.pop(key)
            else:
                fp.append(1.0)
    # False Negatives: keys that were missed by the provider, of course there is some "OCR tolerance" for this.
    # Like if the gold contains {diagnosis: heart problems} and provider returns {diagno$is: heart problems},
    # we still count this with some penalty(check True Positives definition).
    # (everything that is still unmatched is a fn)
    fn = len(gold.keys())
    fp = sum(fp)
    tp = sum(tp)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    return (precision, recall)


def distance(s1, s2):
    return lev.distance(s1, s2)


def score_without_lowerupper_letters(sample, gold, taos=[.5], test=False):
    """
    Scores a 'sample' JSON string against a 'gold' reference.

    :param sample: JSON string to be scored.
    :param gold: Reference 'gold' JSON string.
    :param taos: Optional threshold(s) for the scoring metric (default is [0.5]).
                 The lower the threshold, the most permissive the metric.
    :return: an array of scores for each tao value.
    """
    if not test:
      sample = json.loads(sample)
      gold = json.loads(gold)

    # Convert all keys and values to lowercase strings
    sample = {k.lower(): str(v).lower() for k, v in sample.items()}
    gold = {k.lower(): str(v).lower() for k, v in gold.items()}

    # True Positives: take the output of provider and match it against ground truth.
    tp = []
    # False Positives: the provider returns a key that is not in gold truth
    fp = []
    for sample_key in sample:
        # Is this key in the gold reference?
        if sample_key in gold.keys():
            goldv = gold[sample_key]
            norm_dist = distance(sample[sample_key], goldv) / max(len(sample[sample_key]), len(goldv))
            # Apply the tao threshold on the distance
            tp.append(1 - norm_dist if norm_dist < taos[0] else 0.0)
            gold.pop(sample_key)
        else:
            # Collect candidate keys
            cand_keys = [(k, distance(sample_key, k) / max(len(k), len(sample_key))) for k in gold.keys()]
            cand_keys = [(k, 1 - nd if nd < taos[0] else 0.0) for k, nd in cand_keys]
            cand_keys = [(k, v) for k, v in cand_keys if v > 0.0]
            # If we found candidate keys, move forward; otherwise, don't count a tp
            if cand_keys:
                (key, kscore) = max(cand_keys, key=lambda x: x[1])
                vdist = distance(str(gold[key]), str(sample[sample_key])) / max(len(gold[key]), len(sample[sample_key]))
                vscore = 1 - vdist if vdist < taos[0] else 0.0
                # If we meet the 2 thresholds, count the average of k/v scores
                if vscore > 0.0:
                    tp.append((kscore + vscore) / 2)
                    # Penalize the OCR mismatch
                    fp.append(1 - (kscore + vscore) / 2)
                    gold.pop(key)
            else:
                fp.append(1.0)
    # False Negatives: keys that were missed by the provider
    fn = len(gold.keys())
    fp = sum(fp)
    tp = sum(tp)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    return precision, recall


# Function to process all JSON files and calculate average score
def calculate_average_score(gt_path, results_path):
    total_precision = 0
    total_recall = 0
    count = 0
    files_with_results = 0

    images_with_problems = []
    images_with_results = []

    for filename in os.listdir(gt_path):
        try:
            if filename.endswith('.json'):
                gt_filepath = os.path.join(gt_path, filename)
                results_filepath = os.path.join(results_path, filename)
                print("\nGT:", gt_filepath)
                print("RESULT:", results_filepath)

                if os.path.exists(results_filepath):
                    with open(gt_filepath, 'r', encoding='utf-8') as gt_file:
                        gt_data = gt_file.read()
                    with open(results_filepath, 'r', encoding='utf-8') as results_file:
                        results_data = results_file.read()

                    #### IMPORTANT!!
                    # precision, recall = score(results_data, gt_data)
                    precision, recall = score_without_lowerupper_letters(results_data, gt_data)

                    print(f"... Precision: {precision} Recall: {recall}")
                    total_precision += precision
                    total_recall += recall
                    count += 1
                    files_with_results += 1
                    images_with_results.append(filename)  # Add filename to list of images with results
                else:
                    print("------> ERROR: Result file not found")
                    images_with_problems.append(filename)  # Add filename to list of images with problems

        except Exception as e:
            print("------> ERROR:", e)
            images_with_problems.append(filename)  # Add filename to list of images with problems

    if count > 0:
        avg_precision = total_precision / count
        avg_recall = total_recall / count
    else:
        avg_precision = 0
        avg_recall = 0

    print(f"\nTotal files processed from GT: {count} out of {len(os.listdir(gt_path))}")

    print("\nImages with problems:")
    print(images_with_problems)

    print("\nImages with good results:")
    print(images_with_results)

    return avg_precision, avg_recall

# %% [markdown]
# ## Evaluation

# %%
gt_path = "spark_generic_reports_v6_gt"
results_path = "vLLM_v3_CustomReports01_fixoutput"

# Calculate the average score
avg_precision, avg_recall = calculate_average_score(gt_path, results_path)

# Calculate F1-Score
if avg_precision + avg_recall > 0:
    f1_score = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
else:
    f1_score = 0.0

print(f"\nAverage Precision: {avg_precision}")
print(f"Average Recall: {avg_recall}")
print(f"F1-Score: {f1_score}")
# Out:
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_4.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_4.json
# ... Precision: 0.9724738515430454 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_9.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_9.json
# ... Precision: 0.9425426702339866 Recall: 0.4289934819321714
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_6.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_6.json
# ... Precision: 0.0 Recall: 0.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_4.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_4.json
# ... Precision: 0.8328323388218404 Recall: 0.12188683953065392
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_1.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_1.json
# ... Precision: 0.9747372667883033 Recall: 0.9358177372208407
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json
# ... Precision: 0.9677896653767357 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json
# ------> ERROR: Result file not found
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json
# ... Precision: 0.9353815777821127 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json
# ------> ERROR: Result file not found
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_10.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_10.json
# ... Precision: 0.0 Recall: 0.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json
# ... Precision: 0.9683253219393508 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_6.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_6.json
# ... Precision: 0.9539267828009267 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json
# ... Precision: 0.8283159172301544 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json
# ... Precision: 1.0 Recall: 0.12685982772122162
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_2.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_2.json
# ... Precision: 0.8366630640585636 Recall: 0.4605439091353042
#
# GT: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json
# ... Precision: 0.9240538626954267 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_7.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_7.json
# ... Precision: 0.9664564943253467 Recall: 0.7660935625749701
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json
# ... Precision: 0.9498185650936213 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json
# ... Precision: 0.9683253219393508 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json
# ... Precision: 0.9677896653767357 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json
# ... Precision: 0.9698575418991148 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_5.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_5.json
# ... Precision: 0.9515414562727206 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json
# ... Precision: 0.9217910318195307 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_0.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_0.json
# ... Precision: 0.8946663794049142 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json
# ... Precision: 0.9294049849385562 Recall: 0.9326024446164312
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.json
# ------> ERROR: Result file not found
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json
# ... Precision: 0.977871729212982 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json
# ... Precision: 0.9641447210220558 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json
# ... Precision: 0.9742194677571686 Recall: 0.8631537858265065
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.json
# ------> ERROR: Result file not found
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_0.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_0.json
# ... Precision: 0.9239906044707716 Recall: 0.9526120919488125
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_3.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_3.json
# ... Precision: 0.974339679630054 Recall: 0.2240201390094529
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json
# ... Precision: 0.8159840162492765 Recall: 0.7344294380743218
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_2.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_2.json
# ... Precision: 0.9073303232213323 Recall: 0.9274028546714602
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json
# ... Precision: 0.891019562024055 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_8.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_8.json
# ... Precision: 1.0 Recall: 0.4403287505597897
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_7.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_7.json
# ... Precision: 0.9761315654115934 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_5.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_5.json
# ... Precision: 0.7947000411305012 Recall: 0.07361946493209591
#
# GT: spark_generic_reports_v6_gt/Tempus-Onco_Clinical-Report-Sample_1.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Tempus-Onco_Clinical-Report-Sample_1.json
# ... Precision: 1.0 Recall: 0.32443310910685624
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json
# ... Precision: 0.8981751666792915 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json
# ... Precision: 0.9443641361132218 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json
# ... Precision: 0.9967225538495624 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json
# ... Precision: 1.0 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Sample-NGS-Thyroid-MTC-report_changed_0.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Sample-NGS-Thyroid-MTC-report_changed_0.json
# ... Precision: 0.9541105174909543 Recall: 0.922726221458356
#
# GT: spark_generic_reports_v6_gt/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json
# ... Precision: 0.8810235479281157 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json
# ... Precision: 0.7486425635509562 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_8.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_8.json
# ... Precision: 0.8789886419550599 Recall: 1.0
#
# GT: spark_generic_reports_v6_gt/oncoextra-tnbc-ntrk-wm-sample-report_9.json
# RESULT: vLLM_v3_CustomReports01_fixoutput/oncoextra-tnbc-ntrk-wm-sample-report_9.json
# ... Precision: 0.9698311976818563 Recall: 0.6462867190242831
#
# Total files processed from GT: 63 out of 67
#
# Images with problems:
# ['CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_7.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_6.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_7.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_6.json']
#
# Images with good results:
# ['oncoextra-tnbc-ntrk-wm-sample-report_4.json', 'Tempus-Onco_Clinical-Report-Sample_9.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_15.json', 'Tempus-Onco_Clinical-Report-Sample_6.json', 'Tempus-Onco_Clinical-Report-Sample_4.json', 'oncoextra-tnbc-ntrk-wm-sample-report_1.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_8.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_14.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_16.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_14.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_12.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_22.json', 'Tempus-Onco_Clinical-Report-Sample_10.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_22.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_19.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_3.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_15.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_10.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_8.json', 'oncoextra-tnbc-ntrk-wm-sample-report_6.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_4.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_11.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_17.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_20.json', 'Tempus-Onco_Clinical-Report-Sample_2.json', 'Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEBchanged_0.json', 'oncoextra-tnbc-ntrk-wm-sample-report_7.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_9.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_10.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_16.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_13.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_19.json', 'oncoextra-tnbc-ntrk-wm-sample-report_5.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_12.json', 'Tempus-Onco_Clinical-Report-Sample_0.json', 'Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_0.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_13.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_11.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_21.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_5.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_17.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_1.json', 'oncoextra-tnbc-ntrk-wm-sample-report_0.json', 'Tempus-Onco_Clinical-Report-Sample_3.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_20.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_0.json', 'oncoextra-tnbc-ntrk-wm-sample-report_2.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_5.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_4.json', 'Tempus-Onco_Clinical-Report-Sample_8.json', 'Tempus-Onco_Clinical-Report-Sample_7.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_3.json', 'Tempus-Onco_Clinical-Report-Sample_5.json', 'Tempus-Onco_Clinical-Report-Sample_1.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_9.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_18.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1_2.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_21.json', 'Sample-NGS-Thyroid-MTC-report_changed_0.json', 'CarisReport_2023_NSCLC_KRAS_G12C_PD-L1-unlocked_18.json', 'Caris-Molecular-Intelligence_MI-Profile_Breast_NOS_WEB_1.json', 'oncoextra-tnbc-ntrk-wm-sample-report_8.json', 'oncoextra-tnbc-ntrk-wm-sample-report_9.json']
#
# Average Precision: 0.9226711713606215
# Average Recall: 0.8552668313864051
# F1-Score: 0.8876913007336878

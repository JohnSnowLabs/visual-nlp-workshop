# %% [markdown]
# # Visual Question Answering on Invoices
#
# The aim of this notebook is to show how to apply Visual QA on **RVL_CDIP**

# %%
import logging
logging.getLogger("py4j").setLevel(logging.ERROR)

# %%
imagePath_ = "dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/*"
df = spark.read.format("binaryFile").load(imagePath_).repartition(60).cache()

# %%
df.count()
# Out:
# Out[3]: 39947

# %%
df = df.repartition(256)
df.rdd.getNumPartitions()
# Out:
# Out[4]: 256

# %%
from sparkocr.transformers import *
from sparkocr.enums import *
from pyspark.ml import PipelineModel

binary_to_image = BinaryToImage()\
    .setOutputCol("image") \
    .setImageType(ImageType.TYPE_3BYTE_BGR)

doc_class = VisualDocumentClassifierV3() \
    .pretrained("dit_base_finetuned_rvlcdip", "en", "clinical/ocr") \
    .setInputCols(["image"]) \
    .setOutputCol("label")

# OCR pipeline
ocrpipeline = PipelineModel(stages=[
    binary_to_image,
    doc_class
])

result = ocrpipeline.transform(df).cache()

# %%
result.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = false)
#  |    |-- width: integer (nullable = false)
#  |    |-- nChannels: integer (nullable = false)
#  |    |-- mode: integer (nullable = false)
#  |    |-- resolution: integer (nullable = false)
#  |    |-- data: binary (nullable = true)
#  |-- path: string (nullable = true)
#  |-- modificationTime: timestamp (nullable = true)
#  |-- length: long (nullable = true)
#  |-- pagenum: integer (nullable = true)
#  |-- label: string (nullable = true)
#  |-- exception: string (nullable = true)

# %%
invoices = result.filter(result['label'] == 'invoice')

# %%
from pyspark.sql.functions import rand
from sparkocr.utils import display_images

selected = invoices.orderBy(rand()).limit(5).cache()
display_images(selected)
# Out:
#     Image #0:
#     Origin: dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/form/2061832180.tif
#     Resolution: 72 dpi
#     Width: 788 px
#     Height: 1000 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
#     Image #1:
#     Origin: dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/82895075.tif
#     Resolution: 72 dpi
#     Width: 766 px
#     Height: 1000 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
#     Image #2:
#     Origin: dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/1000789391.tif
#     Resolution: 72 dpi
#     Width: 777 px
#     Height: 1000 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
#     Image #3:
#     Origin: dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/91572983_2984.tif
#     Resolution: 72 dpi
#     Width: 754 px
#     Height: 1000 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
#     Image #4:
#     Origin: dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/2028697397.tif
#     Resolution: 72 dpi
#     Width: 777 px
#     Height: 1000 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3

# %% [markdown]
# ### Let's ask some questions!

# %%
questions = ['What is the total amount invoiced in the document?', 'What is the amount billed in the document?', 'What is the dollar amount mentioned in the document?']

# %%
visual_question_answering = VisualQuestionAnswering()\
    .pretrained("docvqa_donut_base", "en", "clinical/ocr")\
    .setQuestions(questions)\
    .setInputCol(['image']) \
    .setOutputCol("answers")

# %%
totals = visual_question_answering.transform(selected.repartition(5))
totals.select('answers', 'path').show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+
# |answers                                                                                                                                                                                                  |path                                                                 |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+
# |[ What is the total amount invoiced in the document? ->  $100.00,  What is the amount billed in the document? ->  $100.00,  What is the dollar amount mentioned in the document? ->  2061832181]         |dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/form/2061832180.tif      |
# |[ What is the total amount invoiced in the document? ->  400.29,  What is the amount billed in the document? ->  400.29,  What is the dollar amount mentioned in the document? ->  400.29]               |dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/91572983_2984.tif|
# |[ What is the total amount invoiced in the document? ->  $1,600.0,  What is the amount billed in the document? ->  1.600.0,  What is the dollar amount mentioned in the document? ->  $1.600]            |dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/1000789391.tif   |
# |[ What is the total amount invoiced in the document? ->  2.100,-,  What is the amount billed in the document? ->  $1109,  What is the dollar amount mentioned in the document? ->  1109]                 |dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/2028697397.tif   |
# |[ What is the total amount invoiced in the document? ->  $ 62,495.00,  What is the amount billed in the document? ->  $ 50,580.00,  What is the dollar amount mentioned in the document? ->  $ 62,495.00]|dbfs:/mnt/s3_dev/ocr/datasets/RVL-CDIP/test/invoice/82895075.tif     |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+

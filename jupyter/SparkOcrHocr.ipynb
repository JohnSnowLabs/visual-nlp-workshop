# %% [markdown]
# # Example of usage Spark OCR for recognize text and store results to HOCR

# %% [markdown]
# ## Install spark-ocr python packge
# Need specify path to `spark-ocr-assembly-[version].jar` or `secret`

# %%
secret = ""
license = ""
version = secret.split("-")[0]
spark_ocr_jar_path = "../../target/scala-2.11"

# %%
# %%bash
# if python -c 'import google.colab' &> /dev/null; then
#     echo "Run on Google Colab!"
#     echo "Install Open JDK"
#     apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
#     java -version
# fi

# %%
import sys
import os

if 'google.colab' in sys.modules:
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
  os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# %%
# install from PYPI using secret
# %pip install spark-ocr==$version.spark24 --extra-index-url=https://pypi.johnsnowlabs.com/$secret --upgrade

# %%
# or install from local path
# %pip install ../../python/dist/spark-ocr-1.9.0.spark24.tar.gz

# %% [markdown]
# ## Initialization of spark session

# %%
from pyspark.sql import SparkSession
from sparkocr import start

if license:
    os.environ['JSL_OCR_LICENSE'] = license

spark = start(secret=secret, jar_path=spark_ocr_jar_path)
spark
# Out:
# Spark version: 2.4.4
# Spark NLP version: 2.5.5
# Spark OCR version: 1.9.0rc1
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.185:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark OCR</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Import OCR transformers

# %%
from sparkocr.transformers import *
from pyspark.ml import PipelineModel

# %% [markdown]
# ## Define OCR transformers and pipeline

# %%
def pipeline():
    
    # Transforrm PDF document to images per page
    pdf_to_image = PdfToImage()
    pdf_to_image.setInputCol("content")
    pdf_to_image.setOutputCol("image")

    # Run OCR
    ocr = ImageToHocr()
    ocr.setInputCol("image")
    ocr.setOutputCol("hocr")
    ocr.setIgnoreResolution(False)
    
    pipeline = PipelineModel(stages=[
        pdf_to_image,
        ocr
    ])
    
    return pipeline

# %% [markdown]
# ## Read PDF document as binary file

# %%
import pkg_resources
pdf_example = pkg_resources.resource_filename('sparkocr', 'resources/ocr/pdfs/test_document.pdf')
pdf_example_df = spark.read.format("binaryFile").load(pdf_example).cache()

# %% [markdown]
# ## Run OCR pipelines

# %%
result = pipeline().transform(pdf_example_df).cache()

# %% [markdown]
# ## Display results

# %%
result.select("pagenum", "hocr").show()
# Out:
# +-------+--------------------+
# |pagenum|                hocr|
# +-------+--------------------+
# |      0|  <div class='ocr...|
# |      1|  <div class='ocr...|
# +-------+--------------------+

# %% [markdown]
# ### Display hocr as html

# %%
from IPython.core.display import display, HTML
display(HTML(result.select("hocr").collect()[0].hocr))
# Out:
#   <div class='ocr_page' id='page_1' title='image ""; bbox 0 0 5024 6615; ppageno 0'>
#    <div class='ocr_carea' id='block_1_1' title="bbox 2744 526 3324 688">
#     <p class='ocr_par' id='par_1_1' lang='eng' title="bbox 2744 526 3324 688">
#      <span class='ocr_textfloat' id='line_1_1' title="bbox 2905 526 3324 583; baseline -0.007 0; x_size 64.283066; x_descenders 8.2830629; x_ascenders 14">
#       <span class='ocrx_word' id='word_1_1' title='bbox 2905 527 3135 583; x_wconf 95'>Patient</span>
#       <span class='ocrx_word' id='word_1_2' title='bbox 3166 526 3324 581; x_wconf 95'>Nam</span>
#      </span>
#      <span class='ocr_textfloat' id='line_1_2' title="bbox 2744 630 3324 688; baseline -0.002 -1; x_size 63.480278; x_descenders 8.480279; x_ascenders 12">
#       <span class='ocrx_word' id='word_1_3' title='bbox 2744 632 3047 688; x_wconf 91'>Financial</span>
#       <span class='ocrx_word' id='word_1_4' title='bbox 3078 630 3324 687; x_wconf 91'>Numbe</span>
#      </span>
#     </p>
#    </div>
#    <div class='ocr_carea' id='block_1_2' title="bbox 783 708 3332 838">
#     <p class='ocr_par' id='par_1_2' lang='eng' title="bbox 783 708 3332 838">
#      <span class='ocr_textfloat' id='line_1_3' title="bbox 783 708 3332 838; baseline -0.008 -29; x_size 135; x_descenders 34; x_ascenders 25">
#       <span class='ocrx_word' id='word_1_5' title='bbox 783 708 1309 809; x_wconf 96'>Random</span>
#       <span class='ocrx_word' id='word_1_6' title='bbox 1374 708 1900 838; x_wconf 96'>Hospital</span>
#       <span class='ocrx_word' id='word_1_7' title='bbox 2904 738 3059 795; x_wconf 96'>Date</span>
#       <span class='ocrx_word' id='word_1_8' title='bbox 3087 735 3146 793; x_wconf 96'>of</span>
#       <span class='ocrx_word' id='word_1_9' title='bbox 3178 735 3332 792; x_wconf 96'>Birth</span>
#      </span>
#     </p>
#    </div>
#    <div class='ocr_carea' id='block_1_3' title="bbox 2795 840 3346 901">
#     <p class='ocr_par' id='par_1_3' lang='eng' title="bbox 2795 840 3346 901">
#      <span class='ocr_textfloat' id='line_1_4' title="bbox 2795 840 3346 901; baseline -0.005 -6; x_size 65.406593; x_descenders 8.4065933; x_ascenders 12">
#       <span class='ocrx_word' id='word_1_10' title='bbox 2795 842 3026 901; x_wconf 96'>Patient</span>
#       <span class='ocrx_word' id='word_1_11' title='bbox 3057 840 3346 899; x_wconf 96'>Location</span>
#      </span>
#     </p>
#    </div>
#    <div class='ocr_carea' id='block_1_4' title="bbox 321 1128 2269 1150">
#     <p class='ocr_par' id='par_1_4' lang='eng' title="bbox 321 1128 2269 1150">
#      <span class='ocr_line' id='line_1_5' title="bbox 321 1128 325 1137; baseline 0 0; x_size 20; x_descenders 5; x_ascenders 5">
#       <span class='ocrx_word' id='word_1_12' title='bbox 321 1128 325 1137; x_wconf 0'>t</span>
#      </span>
#      <span class='ocr_line' id='line_1_6' title="bbox 322 1136 2269 1150; baseline -0.001 -3; x_size 20; x_descenders 5; x_ascenders 5">
#       <span class='ocrx_word' id='word_1_13' title='bbox 493 1128 531 1156; x_wconf 40'>ere</span>
#       <span class='ocrx_word' id='word_1_14' title='bbox 633 1142 646 1147; x_wconf 28'>st</span>
#       <span class='ocrx_word' id='word_1_15' title='bbox 659 1141 731 1149; x_wconf 46'>eee</span>
#       <span class='ocrx_word' id='word_1_16' title='bbox 768 1143 770 1145; x_wconf 65'>-</span>
#       <span class='ocrx_word' id='word_1_17' title='bbox 855 1138 1437 1150; x_wconf 11'>eR</span>
#       <span class='ocrx_word' id='word_1_18' title='bbox 1373 1128 1439 1156; x_wconf 30'>eo</span>
#       <span class='ocrx_word' id='word_1_19' title='bbox 1499 1140 1541 1147; x_wconf 17'>ee.</span>
#       <span class='ocrx_word' id='word_1_20' title='bbox 1551 1143 1554 1145; x_wconf 0'>-</span>
#       <span class='ocrx_word' id='word_1_21' title='bbox 1565 1138 1664 1147; x_wconf 28'>ee</span>
#       <span class='ocrx_word' id='word_1_22' title='bbox 1683 1142 1698 1145; x_wconf 10'>8</span>
#       <span class='ocrx_word' id='word_1_23' title='bbox 1712 1138 1826 1147; x_wconf 32'>ee</span>
#       <span class='ocrx_word' id='word_1_24' title='bbox 1917 1128 1943 1156; x_wconf 29'>et</span>
#       <span class='ocrx_word' id='word_1_25' title='bbox 2120 1126 2147 1154; x_wconf 40'>——</span>
#       <span class='ocrx_word' id='word_1_26' title='bbox 2146 1136 2269 1146; x_wconf 31'>oe</span>
#      </span>
#     </p>
#    </div>
#    <div class='ocr_carea' id='block_1_5' title="bbox 335 1257 957 1392">
#     <p class='ocr_par' id='par_1_5' lang='eng' title="bbox 335 1257 957 1392">
#      <span class='ocr_line' id='line_1_7' title="bbox 335 1257 879 1318; baseline 0.002 -6; x_size 63.103016; x_descenders 8.1030149; x_ascenders 12">
#       <span class='ocrx_word' id='word_1_27' title='bbox 335 1253 533 1324; x_wconf 96'>Chief</span>
#       <span class='ocrx_word' id='word_1_28' title='bbox 538 1253 882 1324; x_wconf 94'>Complaint</span>
#      </span>
#      <span class='ocr_line' id='line_1_8' title="bbox 339 1338 957 1392; baseline -0.008 0; x_size 61.349247; x_descenders 7.3492465; x_ascenders 15">
#       <span class='ocrx_word' id='word_1_29' title='bbox 339 1338 655 1392; x_wconf 59'>Shortness</span>
#       <span class='ocrx_word' id='word_1_30' title='bbox 679 1339 733 1388; x_wconf 95'>of</span>
#       <span class='ocrx_word' id='word_1_31' title='bbox 762 1340 957 1391; x_wconf 95'>breath</span>
#      </span>
#     </p>
#    </div>
#    <div class='ocr_carea' id='block_1_6' title="bbox 338 1469 1189 1527">
#     <p class='ocr_par' id='par_1_6' lang='eng' title="bbox 338 1469 1189 1527">
#      <span class='ocr_line' id='line_1_9' title="bbox 338 1469 1189 1527; baseline 0 -6; x_size 58.417721; x_descenders 6.4177217; x_ascenders 13">
#       <span class='ocrx_word' id='word_1_32' title='bbox 338 1470 576 1527; x_wconf 96'>History</span>
#       <span class='ocrx_word' id='word_1_33' title='bbox 603 1470 666 1521; x_wconf 96'>of</span>
#       <span class='ocrx_word' id='word_1_34' title='bbox 692 1469 946 1522; x_wconf 96'>Present</span>
#       <span class='ocrx_word' id='word_1_35' title='bbox 975 1469 1189 1521; x_wconf 86'>Illness</span>
#      </span>
#     </p>
#    </div>
#    <div class='ocr_carea' id='block_1_7' title="bbox 329 1701 3184 2632">
#     <p class='ocr_par' id='par_1_7' lang='eng' title="bbox 331 1701 3175 2203">
#      <span class='ocr_line' id='line_1_10' title="bbox 336 1701 3030 1780; baseline -0.003 -13; x_size 69; x_descenders 14; x_ascenders 13">
#       <span class='ocrx_word' id='word_1_36' title='bbox 336 1712 546 1768; x_wconf 94'>Patient</span>
#       <span class='ocrx_word' id='word_1_37' title='bbox 574 1712 621 1767; x_wconf 96'>is</span>
#       <span class='ocrx_word' id='word_1_38' title='bbox 646 1725 716 1767; x_wconf 95'>an</span>
#       <span class='ocrx_word' id='word_1_39' title='bbox 744 1713 1098 1780; x_wconf 73'>84-year-old</span>
#       <span class='ocrx_word' id='word_1_40' title='bbox 1126 1712 1272 1766; x_wconf 27'>male</span>
#       <span class='ocrx_word' id='word_1_41' title='bbox 1299 1711 1418 1763; x_wconf 95'>wilh</span>
#       <span class='ocrx_word' id='word_1_42' title='bbox 1446 1721 1478 1764; x_wconf 95'>a</span>
#       <span class='ocrx_word' id='word_1_43' title='bbox 1504 1713 1633 1775; x_wconf 91'>past</span>
#       <span class='ocrx_word' id='word_1_44' title='bbox 1661 1708 1896 1763; x_wconf 96'>medical</span>
#       <span class='ocrx_word' id='word_1_45' title='bbox 1928 1705 2131 1773; x_wconf 96'>history</span>
#       <span class='ocrx_word' id='word_1_46' title='bbox 2154 1706 2207 1762; x_wconf 96'>of</span>
#       <span class='ocrx_word' id='word_1_47' title='bbox 2235 1708 2654 1773; x_wconf 93'>hypertension,</span>
#       <span class='ocrx_word' id='word_1_48' title='bbox 2684 1701 2902 1769; x_wconf 90'>HFpEF</span>
#       <span class='ocrx_word' id='word_1_49' title='bbox 2927 1704 3030 1758; x_wconf 89'>last</span>
#      </span>
#      <span class='ocr_line' id='line_1_11' title="bbox 333 1789 2852 1858; baseline -0.003 -9; x_size 64; x_descenders 13; x_ascenders 12">
#       <span class='ocrx_word' id='word_

# %% [markdown]
# ## Clear cache

# %%
result.unpersist()

# %% [markdown]
# # Visual Document NER v2

# %%
secret = ""
license = ""
version = secret.split("-")[0]
spark_ocr_jar_path = "../../target/scala-2.11/"
AWS_ACCESS_KEY_ID = ""
AWS_SECRET_ACCESS_KEY = ""

import os
os.environ['JSL_OCR_LICENSE'] = license
os.environ["AWS_ACCESS_KEY_ID"] = AWS_ACCESS_KEY_ID
os.environ["AWS_SECRET_ACCESS_KEY"] = AWS_SECRET_ACCESS_KEY

# %%
#%pip install spark-ocr==$version+spark30 --extra-index-url=https://pypi.johnsnowlabs.com/$secret --upgrade

# %%
#%pip install ../../python/dist/spark-ocr-3.9.0+spark30.tar.gz

# %%
import pyspark
import sparkocr
import json
import os

from pyspark.sql import SparkSession
from pyspark.ml import PipelineModel
import pyspark.sql.functions as f

from sparkocr.transformers import *
from sparkocr.utils import display_images
from sparkocr.enums import *

# %% [markdown]
# ### Initialize Spark session

# %%
from sparkocr import start
from pyspark import SparkConf

spark = start(jar_path = spark_ocr_jar_path)
spark
# Out:
# Spark version: 3.0.2
# Spark NLP version: 3.4.1
# Spark OCR version: 3.15.0rc1
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.147:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark OCR</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Load test images

# %%
import pkg_resources
test_image_path = pkg_resources.resource_filename('sparkocr', 'resources/ocr/forms/form1.jpg')
bin_df = spark.read.format("binaryFile").load(test_image_path)
bin_df.show()
# Out:
# +--------------------+-------------------+------+--------------------+
# |                path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# |file:/home/alexan...|2022-01-13 11:59:17|421333|[FF D8 FF E0 00 1...|
# +--------------------+-------------------+------+--------------------+

# %% [markdown]
# ## Display images

# %%
image_df = BinaryToImage().transform(bin_df)
display_images(image_df)
# Out:
#     Image #0:
#     Origin: file:/home/alexander_jsl/Workspace/spark-ocr/python/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 150 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: ImageType.TYPE_BYTE_GRAY
#     Number of channels: 1
# <PIL.Image.Image image mode=L size=1240x1755 at 0x7F9C5CC02250>

# %% [markdown]
# ### Define pipeline

# %%
binary_to_image = BinaryToImage()\
    .setOutputCol("image") \
    .setImageType(ImageType.TYPE_3BYTE_BGR)

img_to_hocr = ImageToHocr()\
    .setInputCol("image")\
    .setOutputCol("hocr")\
    .setIgnoreResolution(False)\
    .setOcrParams(["preserve_interword_spaces=0"])

tokenizer = HocrTokenizer()\
    .setInputCol("hocr")\
    .setOutputCol("token")

doc_ner = VisualDocumentNerV2()\
    .pretrained("layoutlmv2_key_value_pairs", "en", "clinical/ocr")\
    .setInputCols(["token", "image"])\
    .setOutputCol("entities")

draw = ImageDrawAnnotations() \
    .setInputCol("image") \
    .setInputChunksCol("entities") \
    .setOutputCol("image_with_annotations") \
    .setFontSize(10) \
    .setLineWidth(4)\
    .setRectColor(Color.red)

# OCR pipeline
pipeline = PipelineModel(stages=[
    binary_to_image,
    img_to_hocr,
    tokenizer,
    doc_ner,
    draw
])

# %% [markdown]
# ## Call pipeline

# %%
results = pipeline.transform(bin_df).cache()

# %% [markdown]
# ## Show results

# %%
## since pyspark2.3 doesn't have element_at, 'getItem' is involked
path_array = f.split(results['path'], '/')

# from pyspark2.4
# results.withColumn("filename", f.element_at(f.split("path", "/"), -1)) \

results.withColumn('filename', path_array.getItem(f.size(path_array)- 1)) \
    .withColumn("exploded_entities", f.explode("entities")) \
    .select("filename", "exploded_entities") \
    .show(truncate=False)
# Out:
# +---------+---------------------------------------------------------------------------------------------------------------------------------------------------+
# |filename |exploded_entities                                                                                                                                  |
# +---------+---------------------------------------------------------------------------------------------------------------------------------------------------+
# |form1.jpg|[named_entity, 12, 16, b-question, [x -> 1020, y -> 128, height -> 23, confidence -> 95, token -> study, word -> Study, width -> 61], []]          |
# |form1.jpg|[named_entity, 18, 19, i-question, [x -> 1088, y -> 128, height -> 19, confidence -> 96, token -> id, word -> ID:, width -> 29], []]               |
# |form1.jpg|[named_entity, 25, 35, b-header, [x -> 407, y -> 190, height -> 37, confidence -> 96, token -> institution, word -> Institution, width -> 241], []]|
# |form1.jpg|[named_entity, 37, 40, i-header, [x -> 667, y -> 190, height -> 37, confidence -> 96, token -> name, word -> Name, width -> 130], []]              |
# |form1.jpg|[named_entity, 112, 115, b-question, [x -> 58, y -> 478, height -> 19, confidence -> 92, token -> name, word -> Name:, width -> 69], []]           |
# |form1.jpg|[named_entity, 112, 112, i-question, [x -> 58, y -> 478, height -> 19, confidence -> 92, token -> :, word -> Name:, width -> 69], []]              |
# |form1.jpg|[named_entity, 118, 125, b-answer, [x -> 143, y -> 478, height -> 22, confidence -> 91, token -> dribbler, word -> Dribbler,, width -> 92], []]    |
# |form1.jpg|[named_entity, 118, 118, i-answer, [x -> 143, y -> 478, height -> 22, confidence -> 91, token -> ,, word -> Dribbler,, width -> 92], []]           |
# |form1.jpg|[named_entity, 128, 130, i-answer, [x -> 244, y -> 483, height -> 14, confidence -> 96, token -> aaa, word -> aaa, width -> 36], []]               |
# |form1.jpg|[named_entity, 132, 134, i-answer, [x -> 289, y -> 478, height -> 19, confidence -> 96, token -> bbb, word -> bbb, width -> 41], []]               |
# |form1.jpg|[named_entity, 136, 140, b-question, [x -> 431, y -> 478, height -> 23, confidence -> 96, token -> study, word -> Study, width -> 61], []]         |
# |form1.jpg|[named_entity, 142, 145, i-question, [x -> 500, y -> 478, height -> 19, confidence -> 96, token -> date, word -> Date:, width -> 53], []]          |
# |form1.jpg|[named_entity, 142, 142, i-question, [x -> 500, y -> 478, height -> 19, confidence -> 96, token -> :, word -> Date:, width -> 53], []]             |
# |form1.jpg|[named_entity, 148, 149, b-answer, [x -> 568, y -> 478, height -> 22, confidence -> 96, token -> 12, word -> 12-09-2006,, width -> 129], []]       |
# |form1.jpg|[named_entity, 148, 148, i-answer, [x -> 568, y -> 478, height -> 22, confidence -> 96, token -> -, word -> 12-09-2006,, width -> 129], []]        |
# |form1.jpg|[named_entity, 148, 149, i-answer, [x -> 568, y -> 478, height -> 22, confidence -> 96, token -> 09, word -> 12-09-2006,, width -> 129], []]       |
# |form1.jpg|[named_entity, 148, 148, i-answer, [x -> 568, y -> 478, height -> 22, confidence -> 96, token -> -, word -> 12-09-2006,, width -> 129], []]        |
# |form1.jpg|[named_entity, 148, 151, i-answer, [x -> 568, y -> 478, height -> 22, confidence -> 96, token -> 2006, word -> 12-09-2006,, width -> 129], []]     |
# |form1.jpg|[named_entity, 148, 148, i-answer, [x -> 568, y -> 478, height -> 22, confidence -> 96, token -> ,, word -> 12-09-2006,, width -> 129], []]        |
# |form1.jpg|[named_entity, 160, 160, i-answer, [x -> 705, y -> 478, height -> 19, confidence -> 96, token -> 6, word -> 6:34, width -> 41], []]                |
# +---------+---------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
display_images(results, "image_with_annotations", width=1000)
# Out:
#     Image #0:
#     Origin: file:/home/alexander_jsl/Workspace/spark-ocr/python/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 0 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
# <PIL.Image.Image image mode=RGB size=1240x1755 at 0x7F9C5C0BDC40>

# %% [markdown]
# ## Customize labels

# %%
binary_to_image_ = BinaryToImage()\
    .setOutputCol("image") \
    .setImageType(ImageType.TYPE_3BYTE_BGR)

img_to_hocr_ = ImageToHocr()\
    .setInputCol("image")\
    .setOutputCol("hocr")\
    .setIgnoreResolution(False)\
    .setOcrParams(["preserve_interword_spaces=0"])

tokenizer_ = HocrTokenizer()\
    .setInputCol("hocr")\
    .setOutputCol("token")

doc_ner_cust = VisualDocumentNerV2()\
    .pretrained("layoutlmv2_key_value_pairs", "en", "clinical/ocr")\
    .setInputCols(["token", "image"])\
    .setOutputCol("entities")\
    .setLabels(["other",
                "header",
                "header",
                "key",
                "key",
                "value",
                "value"])\
    .setWhiteList(["header",
                   "key",
                   "value"])

draw_ = ImageDrawAnnotations() \
    .setInputCol("image") \
    .setInputChunksCol("entities") \
    .setOutputCol("image_with_annotations") \
    .setFontSize(10) \
    .setLineWidth(4)\
    .setRectColor(Color.red)


# OCR pipeline
pipeline_cust = PipelineModel(stages=[
    binary_to_image_,
    img_to_hocr_,
    tokenizer_,
    doc_ner_cust,
    draw_
])

results_cust = pipeline_cust.transform(bin_df).cache()
display_images(results_cust, "image_with_annotations", width=1000)
# Out:
#     Image #0:
#     Origin: file:/home/alexander_jsl/Workspace/spark-ocr/python/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 0 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
# <PIL.Image.Image image mode=RGB size=1240x1755 at 0x7F9C5C0D5400>

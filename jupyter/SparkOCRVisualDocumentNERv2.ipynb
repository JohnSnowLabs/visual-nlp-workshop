# %% [markdown]
# # Visual Document NER v2

# %%
secret = ""
license = ""
version = secret.split("-")[0]
spark_ocr_jar_path = "../../target/scala-2.11/"
AWS_ACCESS_KEY_ID = ""
AWS_SECRET_ACCESS_KEY = ""

import os
os.environ['JSL_OCR_LICENSE'] = license
os.environ["AWS_ACCESS_KEY_ID"] = AWS_ACCESS_KEY_ID
os.environ["AWS_SECRET_ACCESS_KEY"] = AWS_SECRET_ACCESS_KEY

# %%
#%pip install spark-ocr==$version+spark30 --extra-index-url=https://pypi.johnsnowlabs.com/$secret --upgrade

# %%
#%pip install ../../python/dist/spark-ocr-3.9.0+spark30.tar.gz

# %%
import pyspark
import sparkocr
import json
import os

from pyspark.sql import SparkSession
from pyspark.ml import PipelineModel
import pyspark.sql.functions as f

from sparkocr.transformers import *
from sparkocr.utils import display_images
from sparkocr.enums import *

# %% [markdown]
# ### Initialize Spark session

# %%
from sparkocr import start
from pyspark import SparkConf

spark = start(jar_path = spark_ocr_jar_path)
spark
# Out:
# Spark version: 3.0.2
# Spark NLP version: 3.3.4
# Spark OCR version: 3.9.1
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.31.94:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark OCR</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Load test images

# %%
import pkg_resources
test_image_path = pkg_resources.resource_filename('sparkocr', 'resources/ocr/forms/form1.jpg')
bin_df = spark.read.format("binaryFile").load(test_image_path)
bin_df.show()
# Out:
# +--------------------+-------------------+------+--------------------+
# |                path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# |file:/home/alexan...|2021-11-14 18:35:03|421333|[FF D8 FF E0 00 1...|
# +--------------------+-------------------+------+--------------------+

# %% [markdown]
# ## Display images

# %%
image_df = BinaryToImage().transform(bin_df)
display_images(image_df)
# Out:
#     Image #0:
#     Origin: file:/home/alexander_jsl/Workspace/spark-ocr/python/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 150 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: ImageType.TYPE_BYTE_GRAY
#     Number of channels: 1
# <PIL.Image.Image image mode=L size=1240x1755 at 0x7FE45511A160>

# %% [markdown]
# ### Define pipeline

# %%
binary_to_image = BinaryToImage()\
    .setOutputCol("image") \
    .setImageType(ImageType.TYPE_3BYTE_BGR)

img_to_hocr = ImageToHocr()\
    .setInputCol("image")\
    .setOutputCol("hocr")\
    .setIgnoreResolution(False)\
    .setOcrParams(["preserve_interword_spaces=0"])

tokenizer = HocrTokenizer()\
    .setInputCol("hocr")\
    .setOutputCol("token")

doc_ner = VisualDocumentNerV2()\
    .pretrained("layoutlmv2_funsd", "en", "clinical/ocr")\
    .setInputCols(["token", "image"])\
    .setOutputCol("entities")

draw = ImageDrawAnnotations() \
    .setInputCol("image") \
    .setInputChunksCol("entities") \
    .setOutputCol("image_with_annotations") \
    .setFontSize(10) \
    .setLineWidth(4)\
    .setRectColor(Color.red)

# OCR pipeline
pipeline = PipelineModel(stages=[
    binary_to_image,
    img_to_hocr,
    tokenizer,
    doc_ner,
    draw
])

# %% [markdown]
# ## Call pipeline

# %%
results = pipeline.transform(bin_df).cache()

# %% [markdown]
# ## Show results

# %%
## since pyspark2.3 doesn't have element_at, 'getItem' is involked
path_array = f.split(results['path'], '/')

# from pyspark2.4
# results.withColumn("filename", f.element_at(f.split("path", "/"), -1)) \

results.withColumn('filename', path_array.getItem(f.size(path_array)- 1)) \
    .withColumn("exploded_entities", f.explode("entities")) \
    .select("filename", "exploded_entities") \
    .show(truncate=False)
# Out:
# +---------+-------------------------------------------------------------------------------------------------------------------------+
# |filename |exploded_entities                                                                                                        |
# +---------+-------------------------------------------------------------------------------------------------------------------------+
# |form1.jpg|[entity, 0, 6, i-answer, [x -> 1027, y -> 89, height -> 19, confidence -> 96, word -> Version:, width -> 90], []]        |
# |form1.jpg|[entity, 25, 35, b-header, [x -> 407, y -> 190, height -> 37, confidence -> 96, word -> Institution, width -> 241], []]  |
# |form1.jpg|[entity, 37, 40, i-header, [x -> 667, y -> 190, height -> 37, confidence -> 96, word -> Name, width -> 130], []]         |
# |form1.jpg|[entity, 42, 52, b-question, [x -> 498, y -> 276, height -> 19, confidence -> 96, word -> Institution, width -> 113], []]|
# |form1.jpg|[entity, 54, 60, i-question, [x -> 618, y -> 276, height -> 19, confidence -> 96, word -> Address, width -> 89], []]     |
# |form1.jpg|[entity, 62, 72, b-question, [x -> 454, y -> 339, height -> 19, confidence -> 96, word -> Institution, width -> 114], []]|
# |form1.jpg|[entity, 74, 80, i-question, [x -> 575, y -> 339, height -> 19, confidence -> 96, word -> Address, width -> 90], []]     |
# |form1.jpg|[entity, 82, 85, i-question, [x -> 673, y -> 339, height -> 19, confidence -> 96, word -> Line, width -> 43], []]        |
# |form1.jpg|[entity, 87, 87, i-question, [x -> 724, y -> 339, height -> 19, confidence -> 96, word -> #2, width -> 24], []]          |
# |form1.jpg|[entity, 87, 87, i-question, [x -> 724, y -> 339, height -> 19, confidence -> 96, word -> #2, width -> 24], []]          |
# |form1.jpg|[entity, 90, 98, b-question, [x -> 497, y -> 402, height -> 23, confidence -> 92, word -> Telephone, width -> 117], []]  |
# |form1.jpg|[entity, 100, 100, i-question, [x -> 622, y -> 402, height -> 19, confidence -> 92, word -> &, width -> 14], []]         |
# |form1.jpg|[entity, 102, 106, i-question, [x -> 645, y -> 402, height -> 19, confidence -> 95, word -> email, width -> 60], []]     |
# |form1.jpg|[entity, 112, 115, b-question, [x -> 58, y -> 478, height -> 19, confidence -> 92, word -> Name:, width -> 69], []]      |
# |form1.jpg|[entity, 112, 112, i-question, [x -> 58, y -> 478, height -> 19, confidence -> 92, word -> Name:, width -> 69], []]      |
# |form1.jpg|[entity, 118, 125, b-answer, [x -> 143, y -> 478, height -> 22, confidence -> 91, word -> Dribbler,, width -> 92], []]   |
# |form1.jpg|[entity, 118, 118, i-answer, [x -> 143, y -> 478, height -> 22, confidence -> 91, word -> Dribbler,, width -> 92], []]   |
# |form1.jpg|[entity, 128, 130, i-answer, [x -> 244, y -> 483, height -> 14, confidence -> 96, word -> aaa, width -> 36], []]         |
# |form1.jpg|[entity, 132, 134, i-answer, [x -> 289, y -> 478, height -> 19, confidence -> 96, word -> bbb, width -> 41], []]         |
# |form1.jpg|[entity, 136, 140, b-question, [x -> 431, y -> 478, height -> 23, confidence -> 96, word -> Study, width -> 61], []]     |
# +---------+-------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
display_images(results, "image_with_annotations", width=1000)
# Out:
#     Image #0:
#     Origin: file:/home/alexander_jsl/Workspace/spark-ocr/python/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 0 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: ImageType.TYPE_3BYTE_BGR
#     Number of channels: 3
# <PIL.Image.Image image mode=RGB size=1240x1755 at 0x7FE45405BC40>

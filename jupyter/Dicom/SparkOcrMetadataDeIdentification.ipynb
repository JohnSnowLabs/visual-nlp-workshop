# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/visual-nlp-workshop/blob/master/jupyter/Dicom/SparkOcrMetadataDeIdentification.ipynb)

# %% [markdown]
# # 🧾 DICOM Metadata De-Identification Pipeline
#
# In this notebook, we demonstrate how to **de-identify DICOM metadata** using
# 🧠 **Healthcare NLP** and 👁️ **Visual NLP** components from John Snow Labs.
#
# The approach follows the methodology described in the blog post below, with this notebook focusing specifically on **metadata-level PHI removal**:
#
# 🔗 https://medium.com/john-snow-labs/de-identifying-dicom-files-a-step-by-step-guide-with-john-snow-labs-visual-nlp-2c21b60f92a8
#
# ---
#
# ## ⚙️ Pipeline Overview
#
# This notebook shows how to build and inspect a DICOM metadata de-identification workflow driven by configurable strategy files.
#
# The workflow covers:
#
# - 🏷️ **Strategy-file based de-identification**, where each DICOM tag is assigned an action such as `cleanTag`, `remove`, `delete`, `hashId`, `patientHashId`, `replaceWithLiteral`, or `replaceWithMapping`
# - 🔒 **Private tag removal** from both top-level DICOM metadata and nested sequences
# - 🗂️ **External mapping support**, allowing selected DICOM tags to be replaced with supplied patient, study, series, SOP, date, or time values
# - 📦 **Group-level strategy rules**, where all tags in selected DICOM groups can be removed or deleted together
# - 🧠 **NER-based metadata cleaning** for tags marked with `cleanTag`
# - 🔍 **Original vs de-identified metadata comparison** to verify tag-level changes
# - 🔑 **UID and Patient ID mapping extraction** for traceability and validation
# - 💾 **Saving de-identified DICOM files** back to disk
#
# This notebook focuses **exclusively on metadata de-identification**
# (no pixel-level PHI removal).
# ---
#
# ## 🧭 Notebook Workflow
#
# The notebook is organized into the following steps:
#
# ### 1️⃣ Configure and Start Spark OCR with Healthcare NLP
# Set the required license variables, install the required packages, and start a Spark session with Visual NLP and Healthcare NLP enabled.
#
# ### 2️⃣ Inspect the DICOM Metadata Strategy File
# Load the default DICOM strategy CSV and review how tags, VRs, actions, and options define metadata de-identification behavior.
#
# ### 3️⃣ Review Available De-Identification Actions
# Explore the supported actions in `DicomMetadataDeidentifier`, including tag removal, value replacement, hashing, date/time shifting, and NER-based cleaning.
#
# ### 4️⃣ Load and Inspect DICOM Files
# Read DICOM files from disk using Spark and extract the original metadata for inspection.
#
# ### 5️⃣ Remove Private DICOM Tags
# Apply `DicomMetadataDeidentifier` with private tag removal enabled and compare the original and cleaned metadata.
#
# ### 6️⃣ Apply External Metadata Mappings
# Create an external mapping DataFrame and use `replaceWithMapping` rules to replace selected DICOM tag values with supplied values.
#
# ### 7️⃣ Apply Group-Level Strategy Rules
# Use a group strategy file to remove or delete all tags belonging to selected DICOM groups, including nested tags.
#
# ### 8️⃣ Run NER-Based Metadata De-Identification
# Extract tags marked with `cleanTag`, pass their text through a Healthcare NLP de-identification pipeline, and write the cleaned values back into the DICOM metadata.
#
# ### 9️⃣ Compare Original vs De-Identified Metadata
# Print tag-level differences between the original metadata and the cleaned metadata to validate the transformation.
#
# ### 🔟 Extract UID and Patient ID Mappings
# Generate mappings between original and de-identified UIDs and patient identifiers for downstream validation and traceability.
#
# ### 1️⃣1️⃣ Save De-Identified DICOM Files
# Write the cleaned DICOM binaries to disk for downstream processing, validation, or deployment.

# %%
license = ""
secret = ""
nlp_secret = ""
aws_access_key = ""
aws_secret_key = ""

version = secret.split("-")[0]
spark_ocr_jar_path = "../../../target/scala-2.12"

# %% [markdown]
# ## Start Spark session

# %%
from sparkocr import start
import os 

if license:
    os.environ['JSL_OCR_LICENSE'] = license
    os.environ['SPARK_NLP_LICENSE'] = license

if aws_access_key:
    os.environ['AWS_ACCESS_KEY'] = aws_access_key
    os.environ['AWS_SECRET_ACCESS_KEY'] = aws_secret_key

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

spark = start(secret=secret,
              nlp_secret=nlp_secret,
              jar_path=spark_ocr_jar_path,
              nlp_internal="6.2.2")

spark
# Out:
# Spark version: 3.4.1
# Spark NLP version: 6.4.2
# Spark NLP for Healthcare version: 6.4.1
# Spark OCR version: 6.4.3rc2
#
# :: loading settings :: url = jar:file:/usr/local/lib/python3.11/dist-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# com.johnsnowlabs.nlp#spark-nlp-gpu_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-10576f5f-c102-4a91-8f6f-4e082185c14f;1.0
# 	confs: [default]
# 	found com.johnsnowlabs.nlp#spark-nlp-gpu_2.12;6.4.2 in central
# 	found com.typesafe#config;1.4.2 in central
# 	found org.rocksdb#rocksdbjni;6.29.5 in central
# 	found com.amazonaws#aws-java-sdk-s3;1.12.500 in central
# 	found com.amazonaws#aws-java-sdk-kms;1.12.500 in central
# 	found com.amazonaws#aws-java-sdk-core;1.12.500 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# ...

# %% [markdown]
# ## Import transformers and annotators

# %%
import os
import json
import sys
import shutil 
import pkg_resources 
import pandas as pd
from textwrap import dedent

from sparknlp.annotator import *
from sparknlp.base import *

import sparknlp_jsl
from sparknlp_jsl.annotator import *

import sparkocr
from sparkocr.transformers import *
from sparkocr.utils import *
from sparkocr.enums import *
from sparkocr.schemas import *

from pyspark.ml import PipelineModel, Pipeline
import pyspark.sql.functions as F
from pyspark.sql.types import *

print(f"Spark NLP version: {sparknlp.version()}")
print(f"Spark NLP internal version: {sparknlp_jsl.version()}")
print(f"Spark OCR version: {sparkocr.version()}")
# Out:
# /tmp/ipykernel_28956/689946903.py:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# Spark NLP version: 6.4.2
# Spark NLP internal version: 6.4.1
# Spark OCR version: 6.4.3rc2

# %%
def build_metadata_comparison_df(dataframe, original_col="metadata_original", cleaned_col="metadata_cleaned"):
    import pandas as pd 
    
    collect_result = []

    for item in dataframe.select("path", original_col, cleaned_col).toLocalIterator():
    
        data = item.asDict()
    
        metadata_original = json.loads(data[original_col])
        metadata_cleaned = json.loads(data[cleaned_col])
    
        for item in metadata_original.keys():
            original_value = metadata_original[item]["value"]
    
            if item not in metadata_cleaned:
                cleaned_value = "DELETED"
            else:
                cleaned_value = metadata_cleaned[item]["value"]
            
            value_changed = False if original_value == cleaned_value else True
            value_deleted = True if original_value != "DELETED" and cleaned_value == "DELETED" else False
            
            collect_result.append([item, metadata_original[item]["vr"], original_value, cleaned_value, value_changed, value_deleted])

    columns = ["Tag", "VR", "Original_Value", "Cleaned_Value", "Is_Changed", "Is_Deleted"]
    metadata_result_df = pd.DataFrame(collect_result, columns=columns)
    
    return metadata_result_df

# %% [markdown]
# <h2>Dicom Metadata Strategy File</h2>
#
# <p>
#   <code>Tags</code>: The DICOM tag in <code>"(group, element)"</code> format.
# </p>
#
# <p>
#   <code>VR</code>: The DICOM Value Representation, such as <code>DA</code>,
#   <code>DT</code>, <code>PN</code>, or <code>UI</code>.
# </p>
#
# <p>
#   <code>Name</code>: The human-readable name of the DICOM tag.
# </p>
#
# <p>
#   <code>Status</code>: Whether a tag is marked Retired in dicom standard.
#   <code>NaN</code> means that tag is not retired.
# </p>
#
# <p>
#   <code>Action</code>: The de-identification operation applied to the tag.
# </p>
#
# <p>
#   <code>Option</code>: An optional parameter used by certain actions.
#   <code>NaN</code> means that no option is supplied.
# </p>

# %%
default_csv_path = pkg_resources.resource_filename('sparkocr', "resources/ocr/dicom/midi_b_strategy_with_tcia.csv")

strategy_df = pd.read_csv(default_csv_path)

strategy_df.head()
# Out:
#            Tags  VR                                 Name Status  \
# 0  (0008, 002A)  DT                 Acquisition DateTime    NaN
# 1  (0008, 009C)  PN          Consulting Physician's Name    NaN
# 2  (0008, 010D)  UI  Context Group Extension Creator UID    NaN
# 3  (0010, 21D0)  DA                  Last Menstrual Date    NaN
# 4  (0010, 21F0)  LO       Patient's Religious Preference    NaN
#
#                       Action Option
# 0  shiftDateByRandomNbOfDays    NaN
# 1                     remove    NaN
# 2                     hashId    NaN
# 3  shiftDateByRandomNbOfDays    NaN
# 4                     remove    NaN

# %% [markdown]
# <h2>🔐 Available De-identification Actions</h2>
#
# <p>
#   The following actions can be configured in the <code>Action</code> column of
#   the DICOM de-identification strategy file.
# </p>
#
# <hr>
#
# <h3><font color="#1565C0">👤 Age De-identification</font></h3>
#
# <h4><code>capAgeAt99IfOver90</code></h4>
#
# <p>
#   Caps the patient's age at <strong>99</strong> when the original age is
#   greater than 90.
# </p>
#
# <hr>
#
# <h3><font color="#2E7D32">📝 Free-Text De-identification</font></h3>
#
# <h4><code>cleanTag</code></h4>
#
# <p>
#   Applies NER-based de-identification to a DICOM tag containing free text.
#   Sensitive entities detected in the text can be removed, replaced with their
#   entity labels, or masked using asterisks.
# </p>
#
# <p><strong>Supported options</strong></p>
#
# <ul>
#   <li>
#     <code>remove</code> — removes the detected PHI from the text.
#   </li>
#   <li>
#     <code>deid</code> — replaces the detected PHI with its corresponding
#     entity label enclosed in angle brackets.
#   </li>
#   <li>
#     <code>mask</code> — replaces each detected PHI value with the same number
#     of asterisk (<code>*</code>) characters, preserving its original length.
#   </li>
# </ul>
#
# <p><strong><font color="#C62828">Original value</font></strong></p>
#
# <pre><code>Dr. Jones asked 284433 to get a CT scan on 28/02/1999</code></pre>
#
# <p><strong><font color="#2E7D32">Option: <code>remove</code></font></strong></p>
#
# <pre><code>asked to get a CT scan on</code></pre>
#
# <p><strong><font color="#2E7D32">Option: <code>deid</code></font></strong></p>
#
# <pre><code>&lt;PROFESSION&gt; &lt;NAME&gt; asked &lt;ID&gt; to get a CT scan on &lt;DATE&gt;</code></pre>
#
# <p><strong><font color="#2E7D32">Option: <code>mask</code></font></strong></p>
#
# <pre><code>*** ***** asked ****** to get a CT scan on **********</code></pre>
#
# <hr>
#
# <h3><font color="#C62828">🗑️ Tag Removal</font></h3>
#
# <h4><code>delete</code></h4>
#
# <p>
#   Deletes the complete DICOM tag from the dataset.
# </p>
#
# <h4><code>remove</code></h4>
#
# <p>
#   Removes the value associated with the DICOM tag.
# </p>
#
# <hr>
#
# <h3><font color="#00838F">➕ Required Tag Creation</font></h3>
#
# <h4><code>ensureTagExists</code></h4>
#
# <p>
#   Ensures that the specified DICOM tag exists in the dataset.
# </p>
#
# <p>
#   If the tag is missing, it is created using the
#   <strong>DICOM-standard-specific empty value for the tag's VR</strong>.
# </p>
#
# <p>
#   The default value therefore depends on the Value Representation of the tag.
# </p>
#
# <hr>
#
# <h3><font color="#6A1B9A">🔑 Identifier De-identification</font></h3>
#
# <h4><code>hashId</code></h4>
#
# <p>
#   Replaces the original identifier with a hashed value.
# </p>
#
# <h4><code>patientHashId</code></h4>
#
# <p>
#   Replaces the original identifier with a patient-specific hashed value.
# </p>
#
# <hr>
#
# <h3><font color="#EF6C00">🔄 Value Replacement</font></h3>
#
# <h4><code>replaceWithLiteral</code></h4>
#
# <p>
#   Replaces the original tag value with the literal value supplied in the
#   <code>Option</code> column.
# </p>
#
# <p>
#   For example, when <code>Option</code> is
#   <code>&lt;REMOVED&gt;</code>, the original value is replaced with
#   <code>&lt;REMOVED&gt;</code>.
# </p>
#
# <pre><code>Tags,VR,Name,Status,Action,Option
# "(0010,0010)",PN,Patient Name,,replaceWithLiteral,&lt;REMOVED&gt;</code></pre>
#
# <h4><code>replaceWithMapping</code></h4>
#
# <p>
#   Replaces the original tag value using an externally supplied mapping.
# </p>
#
# <p>
#   The <code>Option</code> column controls whether occurrences of the tag inside
#   nested DICOM sequences are also replaced.
# </p>
#
# <p>
#   Set <code>Option</code> to <code>Nested</code> to replace the tag at both
#   the top level and inside DICOM sequences.
# </p>
#
# <pre><code>Tags,VR,Name,Status,Action,Option
# "(0008,0018)",UI,SOP Instance UID,,replaceWithMapping,Nested</code></pre>
#
# <h4><code>replaceWithRandomName</code></h4>
#
# <p>
#   Replaces the original person name with a randomly generated name.
# </p>
#
# <hr>
#
# <h3><font color="#388E3C">📅 Date, Time and Age Shifting</font></h3>
#
# <h4><code>shiftAgeByRandom</code></h4>
#
# <p>
#   Shifts the original age by a randomly generated amount.
# </p>
#
# <h4><code>shiftDateByFixedNbOfDays</code></h4>
#
# <p>
#   Shifts the original date by a fixed number of days. The
#   <code>Option</code> value specifies the size of the date jump.
# </p>
#
# <ul>
#   <li>A positive value shifts the date forward.</li>
#   <li>A negative value shifts the date backward.</li>
# </ul>
#
# <pre><code>Tags,VR,Name,Status,Action,Option
# "(0008,0020)",DA,Study Date,,shiftDateByFixedNbOfDays,30</code></pre>
#
# <p>
#   In this example, the Study Date is shifted forward by
#   <strong>30 days</strong>.
# </p>
#
# <h4><code>shiftDateByRandomNbOfDays</code></h4>
#
# <p>
#   Shifts the original date by a randomly selected number of days.
# </p>
#
# <h4><code>shiftTimeByRandom</code></h4>
#
# <p>
#   Shifts the original DICOM time value by a randomly generated amount.
# </p>
#
# <h4><code>shiftUnixTimeStampRandom</code></h4>
#
# <p>
#   Shifts the original Unix timestamp by a randomly generated amount.
# </p>

# %%
DicomMetadataDeidentifier().valid_actions
# Out:
# {'capAgeAt99IfOver90',
#  'cleanTag',
#  'delete',
#  'ensureTagExists',
#  'hashId',
#  'patientHashId',
#  'remove',
#  'replaceWithDummyGraphicalAnnotation',
#  'replaceWithDummyPersonIdentificationCode',
#  'replaceWithLiteral',
#  'replaceWithMapping',
#  'replaceWithRandomName',
#  'replacewithDummyVerifyingObserverIdentificationSequence',
#  'shiftAgeByRandom',
#  'shiftDateByFixedNbOfDays',
#  'shiftDateByRandomNbOfDays',
#  'shiftTimeByRandom',
#  'shiftUnixTimeStampRandom'}

# %% [markdown]
# ## Load Dicom File

# %%
midib_root_path = "./../data/dicom/David_Douglas.dcm"

dicom_df = spark.read.format("binaryFile").load(midib_root_path)

dicom_df.columns
# Out:
# ['path', 'modificationTime', 'length', 'content']

# %% [markdown]
# <h2>Removing Private DICOM Tags</h2>
#
# <p>
#   Configure <code>DicomMetadataDeidentifier()</code> with
#   <code>.setRemovePrivateTags(True)</code> to remove private DICOM tags.
# </p>
#
# <p>
#   This removes private tags from both the top-level DICOM dataset and nested
#   sequences.
# </p>
#
# <pre><code>DicomMetadataDeidentifier().setRemovePrivateTags(True)</code></pre>

# %%
original_metadata = DicomToMetadata() \
    .setInputCol("content") \
    .setOutputCol("metadata_original") \
    .setKeepInput(False) \
    .setExtractTagForNer(False)

dicom_deidentifier = DicomMetadataDeidentifier() \
    .setInputCols(["path"]) \
    .setOutputCol("dicom_private_tag_cleaned") \
    .setKeepInput(True) \
    .setRemovePrivateTags(True) \
    .setStrategyFile(default_csv_path)

deid_metadata = DicomToMetadata() \
    .setInputCol("dicom_private_tag_cleaned") \
    .setOutputCol("metadata_cleaned") \
    .setKeepInput(True) \
    .setExtractTagForNer(False)

pipeline = PipelineModel(stages=[
    original_metadata,
    dicom_deidentifier,
    deid_metadata
])

# %%
result = pipeline.transform(dicom_df).cache()
result.columns
# Out:
# /usr/local/lib/python3.11/dist-packages/pyspark/sql/dataframe.py:169: UserWarning: DataFrame.sql_ctx is an internal property, and will be removed in future releases. Use DataFrame.sparkSession instead.
#   warnings.warn(
# ['exception',
#  'dicom_private_tag_cleaned',
#  'path',
#  'metadata_original',
#  'external_mapping',
#  'metadata_cleaned']

# %%
metadata_result_df = build_metadata_comparison_df(dataframe=result, original_col="metadata_original", cleaned_col="metadata_cleaned")
metadata_result_df.head(5)
# Out:
# 10:50:50, INFO Run DicomToMetadata                                  (0 + 1) / 1]
# 10:50:59, INFO DicomToMetadata : Returning Metadata
# 10:51:04, INFO Run DicomMetadataDeidentifier
# 10:51:04, INFO DicomMetadataDeidentifier Path: /workspace/visual-nlp-workshop/jupyter/data/dicom/David_Douglas.dcm
# 10:51:10, INFO DicomMetadataDeidentifier : Tag '0008002A' Present in Strategy file but missing in Dicom.
# 10:51:10, INFO DicomMetadataDeidentifier : Tag '0008009C' Present in Strategy file but missing in Dicom.
# 10:51:10, INFO DicomMetadataDeidentifier : Tag '0008010D' Present in Strategy file but missing in Dicom.
# 10:51:10, INFO DicomMetadataDeidentifier : Tag '001021D0' Present in Strategy file but missing in Dicom.
# 10:51:10, INFO DicomMetadataDeidentifier : Tag '001021F0' Present in Strategy file but missing in Dicom.
# 10:51:10, INFO DicomMetadataDeidentifier : Tag '0018700C' Present in Strategy file but missing in Dicom.
# ...

# %%
metadata_result_df[metadata_result_df["Is_Deleted"] == True].head(20)
# Out:
#          Tag  VR Original_Value Cleaned_Value  Is_Changed  Is_Deleted
# 25  00090010  LO       FDMS 1.0       DELETED        True        True
# 32  00130010  LO            CTP       DELETED        True        True
# 54  00190010  LO       FDMS 1.0       DELETED        True        True
# 63  00210010  LO       FDMS 1.0       DELETED        True        True
# 64  00250010  LO       FDMS 1.0       DELETED        True        True
# 81  00290010  LO       FDMS 1.0       DELETED        True        True

# %%
metadata_result_df[(metadata_result_df["Is_Changed"] == True) & (metadata_result_df["Is_Deleted"] == False)].head(20)
# Out:
#                      Tag  VR                                Original_Value  \
# 2               00080018  UI  2.25.112784503178059210578740147414000844278
# 3               00080020  DA                                      20130713
# 4               00080021  DA                                      20130713
# 5               00080022  DA                                      20130713
# 6               00080023  DA                                      20130713
# 7               00080030  TM                                        085957
# 8               00080031  TM                                    090020.000
# 9               00080032  TM                                    090020.408
# 10              00080033  TM                                    090143.249
# 11              00080050  SH                               20130714E864535
# 14              00080080  LO                      Scott Community Hospital
# ...

# %% [markdown]
# <h2>Supplying External Values to DICOM Metadata De-identifier</h2>
# <p>
#   <code>DicomMetadataDeidentifier</code> supports file-level metadata
#   replacement using externally supplied ground-truth values.
# </p>

# %%
@F.udf(returnType=StringType())
def get_base_path(path):
    return os.path.basename(path) if path else None

# %% [markdown]
# <h3>External Mapping Schema</h3>
#
# <p>
#   Create the external mapping DataFrame using the predefined
#   <code>dicomExternalSchema</code>.
# </p>
#
# <ul>
#   <li>
#     <code>path</code>: The path or filename used to identify the DICOM file.
#   </li>
#   <li>
#     <code>external_mapping</code>: A map of DICOM tags to their replacement values and
#     value types.
#   </li>
# </ul>
#
# <pre><code>path: String
# mapping: Map[DICOM tag, (replacement value, value type)]</code></pre>
#
# <p>
#   DICOM tags must be provided without parentheses or commas. For example,
#   use <code>00100020</code> instead of <code>(0010,0020)</code>.
# </p>
#
# <h3>Replacement Value Types</h3>
#
# <p>
#   Each replacement value includes a numeric identifier specifying its target
#   data type:
# </p>
#
# <ul>
#   <li><code>0</code> — Integer (<code>int</code>)</li>
#   <li><code>1</code> — Floating-point number (<code>float</code>)</li>
#   <li><code>2</code> — String (<code>str</code>)</li>
# </ul>
#
# <h3>Joining by Path</h3>
#
# <p>
#   The external mapping DataFrame must be joined with the DICOM DataFrame using
#   the file path. Therefore, the path values in both DataFrames must match.
# </p>

# %%
data = [
    (
        "David_Douglas.dcm",
        {
            "00080016": ("1.1.111.1.1.1111111.1.111.111111111111", 2),
            "00080018": ("1.1.111.1.1.1111111.1.111.111111111111", 2),
            "00080020": ("20160729", 2),
            "00080021": ("20160729", 2),
            "00080022": ("20160729", 2),
            "00080023": ("20160729", 2),
            "00100010": ("JOHN^DOE", 2),
            "00100020": ("111111", 2),
            "0020000D": ("1.1.111.1.1.1111111.1.111.111111111111", 2),
            "0020000E": ("1.1.111.1.1.1111111.1.111.111111111111", 2),
            "0040A121": ("20160729", 2),
            "0040A122": ("103", 2),
        },
    )
]

external_mapping_df = spark.createDataFrame(data, dicomExternalSchema) \
    .withColumn("base_path", get_base_path(col("path"))).drop("path")

external_mapping_df.select(F.explode("external_mapping")).show(100, False)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------+-------------------------------------------+
# |key     |value                                      |
# +--------+-------------------------------------------+
# |0020000D|{1.1.111.1.1.1111111.1.111.111111111111, 2}|
# |0020000E|{1.1.111.1.1.1111111.1.111.111111111111, 2}|
# |00100010|{JOHN^DOE, 2}                              |
# |00100020|{111111, 2}                                |
# |0040A121|{20160729, 2}                              |
# |0040A122|{103, 2}                                   |
# |00080021|{20160729, 2}                              |
# |00080020|{20160729, 2}                              |
# |00080018|{1.1.111.1.1.1111111.1.111.111111111111, 2}|
# |00080016|{1.1.111.1.1.1111111.1.111.111111111111, 2}|
# |00080023|{20160729, 2}                              |
# |00080022|{20160729, 2}                              |
# +--------+-------------------------------------------+

# %% [markdown]
# <h3>
#   <font color="#1565C0">1. Required Strategy File Configuration</font>
# </h3>
#
# <p>
#   Every tag that should receive an externally supplied value must use
#   <code>replaceWithMapping</code> in the strategy file.
# </p>
#
# <p>
#   Set <code>Option</code> to <code>Nested</code> when matching tags must also
#   be replaced inside DICOM sequences. Leave it empty when replacement is
#   required only at the top level.
# </p>
#
# <pre><code>Tags,VR,Name,Status,Action,Option
# "(0010,0020)",LO,Patient ID,,replaceWithMapping,
# "(0008,0018)",UI,SOP Instance UID,,replaceWithMapping,Nested</code></pre>
#
# <p>
#   <font color="#1565C0"><strong>Key point:</strong></font>
#   The external mapping supplies the replacement value, while
#   <code>replaceWithMapping</code> triggers the replacement.
# </p>
#
# <hr>
#
# <h3>
#   <font color="#6A1B9A">2. Supplying the Strategy Configuration</font>
# </h3>
#
# <p>
#   The strategy can be supplied to <code>DicomMetadataDeidentifier</code>
#   in either of the following ways:
# </p>
#
# <ul>
#   <li>
#     Use <code>setStrategyFile()</code> to provide the path to a strategy CSV
#     file.
#   </li>
#   <li>
#     Use <code>_set(strategyFileContent=csv_data)</code> to provide the strategy
#     CSV content directly as a string.
#   </li>
# </ul>
#
# <hr>
#
# <h3>
#   <font color="#2E7D32">3. Supplying the CSV Content Directly</font>
# </h3>
#
# <p>
#   Use <code>strategyFileContent</code> when the strategy CSV data is already
#   available as a string.
# </p>
#
# <pre><code>dicom_metadata_deidentifier = DicomMetadataDeidentifier()._set(strategyFileContent=csv_data)</code></pre>
#
# <hr>
#
# <h3>
#   <font color="#EF6C00">4. Supplying a Strategy File Path</font>
# </h3>
#
# <p>
#   Alternatively, use <code>setStrategyFile()</code> to provide the path to a
#   strategy CSV file.
# </p>
#
# <pre><code>dicom_metadata_deidentifier = DicomMetadataDeidentifier().setStrategyFile("/path/to/strategy.csv")</code></pre>
#
# <hr>
#
# <h3>
#   <font color="#C62828">5. Default Strategy</font>
# </h3>
#
# <p>
#   If neither the strategy file path nor the strategy file content is supplied,
#   <code>DicomMetadataDeidentifier</code> uses its default strategy file.
# </p>

# %%
csv_data = dedent("""\
    Tags,VR,Name,Status,Action,Option
    "(0008, 0016)",UI,SOP Class UID,,replaceWithMapping,,
    "(0008, 0018)",UI,SOP Instance UID,,replaceWithMapping,,
    "(0008, 0020)",DA,Study Date,,replaceWithMapping,,
    "(0008, 0021)",DA,Series Date,,replaceWithMapping,,
    "(0008, 0022)",DA,Acquisition Date,,replaceWithMapping,,
    "(0008, 0023)",DA,Content Date,,replaceWithMapping,,
    "(0010, 0010)",PN,Patient's Name,,replaceWithMapping,,
    "(0010, 0020)",LO,Patient ID,,replaceWithMapping,,
    "(0020, 000D)",UI,Study Instance UID,,replaceWithMapping,,
    "(0020, 000E)",UI,Series Instance UID,,replaceWithMapping,,
    "(0040, A121)",DA,Date,,replaceWithMapping,,
    "(0040, A122)",TM,Time,,replaceWithMapping,,
""")

# %%
original_metadata = DicomToMetadata() \
    .setInputCol("content") \
    .setOutputCol("metadata_original") \
    .setKeepInput(False) \
    .setExtractTagForNer(False)

dicom_deidentifier = DicomMetadataDeidentifier() \
    .setInputCols(["path"]) \
    .setOutputCol("dicom_private_external_tag_cleaned") \
    .setKeepInput(True) \
    .setRemovePrivateTags(True) \
    .setExternalMappingCol("external_mapping") \
    ._set(strategyFileContent=csv_data)

deid_metadata = DicomToMetadata() \
    .setInputCol("dicom_private_external_tag_cleaned") \
    .setOutputCol("metadata_cleaned") \
    .setKeepInput(True) \
    .setExtractTagForNer(False)

pipeline = PipelineModel(stages=[
    original_metadata,
    dicom_deidentifier,
    deid_metadata
])

# %%
combined_df = dicom_df.withColumn("base_path", get_base_path(col("path"))) \
    .join(external_mapping_df, on="base_path", how="inner").drop("base_path")

result = pipeline.transform(combined_df).cache()
result.columns
# Out:
# /usr/local/lib/python3.11/dist-packages/pyspark/sql/dataframe.py:169: UserWarning: DataFrame.sql_ctx is an internal property, and will be removed in future releases. Use DataFrame.sparkSession instead.
#   warnings.warn(
# ['exception',
#  'dicom_private_external_tag_cleaned',
#  'path',
#  'external_mapping',
#  'metadata_original',
#  'metadata_cleaned']

# %%
metadata_result_df = build_metadata_comparison_df(dataframe=result, original_col="metadata_original", cleaned_col="metadata_cleaned")
metadata_result_df.head(5)
# Out:
# 10:51:27, INFO Run DicomToMetadata                                  (0 + 1) / 1]
# 10:51:28, INFO DicomToMetadata : Returning Metadata
# 10:51:32, INFO Run DicomMetadataDeidentifier
# 10:51:32, INFO DicomMetadataDeidentifier Path: /workspace/visual-nlp-workshop/jupyter/data/dicom/David_Douglas.dcm
# 10:51:38, INFO DicomMetadataDeidentifier :  Tag '00080016' Marked for 'replaceWithMapping' with Nesting 'False'
# 10:51:38, INFO DicomMetadataDeidentifier :  Tag '00080016' Value Replaced with '1.1.111.1.1.1111111.1.111.111111111111'
# 10:51:38, INFO DicomMetadataDeidentifier :  Tag '00080018' Marked for 'replaceWithMapping' with Nesting 'False'
# 10:51:38, INFO DicomMetadataDeidentifier :  Tag '00080018' Value Replaced with '1.1.111.1.1.1111111.1.111.111111111111'
# 10:51:38, INFO DicomMetadataDeidentifier :  Tag '00080020' Marked for 'replaceWithMapping' with Nesting 'False'
# 10:51:38, INFO DicomMetadataDeidentifier :  Tag '00080020' Value Replaced with '20160729'
# ...

# %%
metadata_result_df[(metadata_result_df["Is_Changed"] == True) & (metadata_result_df["Is_Deleted"] == False)].head(20)
# Out:
#          Tag  VR                                Original_Value  \
# 1   00080016  UI                     1.2.840.10008.5.1.4.1.1.1
# 2   00080018  UI  2.25.112784503178059210578740147414000844278
# 3   00080020  DA                                      20130713
# 4   00080021  DA                                      20130713
# 5   00080022  DA                                      20130713
# 6   00080023  DA                                      20130713
# 26  00100010  PN                              DAVIDSON^DOUGLAS
# 27  00100020  LO                                     292821506
# 55  0020000D  UI  2.25.106461954783291641048254423668956446198
# 56  0020000E  UI   2.25.22373700284337223907674770690654453238
#
#                              Cleaned_Value  Is_Changed  Is_Deleted
# 1   1.1.111.1.1.1111111.1.111.111111111111        True       False
# 2   1.1.111.1.1.1111111.1.111.111111111111        True       False
# 3                                 20160729        True       False
# ...

# %% [markdown]
# <h2>
#   <font color="#1565C0">Group-Level DICOM Strategy File</font>
# </h2>
#
# <p>
#   A group strategy file allows DICOM tags to be targeted by their
#   <strong>group number</strong> instead of configuring each tag individually.
# </p>
#
# <hr>
#
# <h3>
#   <font color="#6A1B9A">1. Targeting Tags by Group</font>
# </h3>
#
# <p>
#   Supply the DICOM group number to identify all tags belonging to that group.
#   The configured action is then applied to every tag within the specified
#   group.
# </p>
#
# <p>
#   For example, targeting group <code>0010</code> applies the action to all
#   Patient Information tags belonging to that group.
# </p>
#
# <p>
#   <font color="#6A1B9A"><strong>Key point:</strong></font>
#   The strategy operates at the group level rather than requiring a separate
#   rule for every individual DICOM tag.
# </p>
#
# <hr>
#
# <h3>
#   <font color="#2E7D32">2. Top-Level and Nested Tags</font>
# </h3>
#
# <p>
#   By default, the configured action is applied to matching group tags
#   everywhere in the DICOM dataset, including:
# </p>
#
# <ul>
#   <li>Tags at the top level of the DICOM dataset</li>
#   <li>Tags inside nested DICOM sequences</li>
# </ul>
#
# <p>
#   No additional nested option is required.
# </p>
#
# <hr>
#
# <h3>
#   <font color="#C62828">3. Supported Actions</font>
# </h3>
#
# <p>
#   Group-level strategies support the following two actions:
# </p>
#
# <ul>
#   <li>
#     <code>remove</code>: Removes the values associated with all tags belonging
#     to the specified group.
#   </li>
#   <li>
#     <code>delete</code>: Deletes all tags belonging to the specified group from
#     the DICOM dataset.
#   </li>
# </ul>
#
# <hr>
#
# <h3>
#   <font color="#EF6C00">4. Supplying the Group Strategy</font>
# </h3>
#
# <p>
#   The group strategy can be supplied to
#   <code>DicomMetadataDeidentifier</code> in either of the following ways:
# </p>
#
# <ul>
#   <li>
#     Use <code>._set(groupStrategyFileContent=csv_group_data)</code> to provide the group
#     strategy CSV data directly as a string.
#   </li>
#   <li>
#     Use <code>setGroupStrategyFile()</code> to provide the path to a group
#     strategy CSV file.
#   </li>
# </ul>
#
# <hr>
#
# <h3>
#   <font color="#2E7D32">5. Supplying the CSV Content Directly</font>
# </h3>
#
# <pre><code>dicom_metadata_deidentifier = DicomMetadataDeidentifier()._set(groupStrategyFileContent=csv_group_data)</code></pre>
#
# <hr>
#
# <h3>
#   <font color="#EF6C00">6. Supplying a Group Strategy File Path</font>
# </h3>
#
# <pre><code>dicom_metadata_deidentifier = DicomMetadataDeidentifier().setGroupStrategyFile("/path/to/group_strategy.csv")</code></pre>
#
# <p>
#   Both approaches configure the same group-level behavior. The only difference
#   is whether the strategy is supplied directly as CSV content or loaded from a
#   file path.
# </p>

# %%
csv_group_data = dedent("""\
    Tags,VR,Name,Status,Action,Option
    "(0020,)",GROUP,None,,delete,
    "(0040,)",GROUP,None,,delete,
""")

csv_data = dedent("""\
    Tags,VR,Name,Status,Action,Option
    "(0008, 0020)",DA,Study Date,,shiftDateByFixedNbOfDays,30,
    "(0008, 0021)",DA,Series Date,,shiftDateByFixedNbOfDays,-30,
    "(0008, 0022)",DA,Acquisition Date,,shiftDateByFixedNbOfDays,10,
    "(0008, 0023)",DA,Content Date,,shiftDateByFixedNbOfDays,-10,
""")

# %%
original_metadata = DicomToMetadata() \
    .setInputCol("content") \
    .setOutputCol("metadata_original") \
    .setKeepInput(False) \
    .setExtractTagForNer(False)

dicom_deidentifier = DicomMetadataDeidentifier() \
    .setInputCols(["path"]) \
    .setOutputCol("dicom_private_external_tag_cleaned") \
    .setKeepInput(True) \
    .setRemovePrivateTags(True) \
    ._set(strategyFileContent=csv_data) \
    ._set(groupStrategyFileContent=csv_group_data)

deid_metadata = DicomToMetadata() \
    .setInputCol("dicom_private_external_tag_cleaned") \
    .setOutputCol("metadata_cleaned") \
    .setKeepInput(True) \
    .setExtractTagForNer(False)

pipeline = PipelineModel(stages=[
    original_metadata,
    dicom_deidentifier,
    deid_metadata
])

# %%
result = pipeline.transform(dicom_df).cache()
result.columns
# Out:
# /usr/local/lib/python3.11/dist-packages/pyspark/sql/dataframe.py:169: UserWarning: DataFrame.sql_ctx is an internal property, and will be removed in future releases. Use DataFrame.sparkSession instead.
#   warnings.warn(
# ['exception',
#  'dicom_private_external_tag_cleaned',
#  'path',
#  'metadata_original',
#  'external_mapping',
#  'metadata_cleaned']

# %%
metadata_result_df = build_metadata_comparison_df(dataframe=result, original_col="metadata_original", cleaned_col="metadata_cleaned")
metadata_result_df.head(5)
# Out:
# 10:51:53, INFO Run DicomToMetadata
# 10:51:53, INFO DicomToMetadata : Returning Metadata
# 10:51:53, INFO Run DicomMetadataDeidentifier
# 10:51:53, INFO DicomMetadataDeidentifier Path: /workspace/visual-nlp-workshop/jupyter/data/dicom/David_Douglas.dcm
# 10:51:53, INFO DicomMetadataDeidentifier : Updating Tag '00080020' VR 'DA'
# 10:51:53, INFO DicomMetadataDeidentifier : Updating Tag '00080021' VR 'DA'
# 10:51:53, INFO DicomMetadataDeidentifier : Updating Tag '00080022' VR 'DA'
# 10:51:53, INFO DicomMetadataDeidentifier : Updating Tag '00080023' VR 'DA'
# 10:51:53, INFO DicomMetadataDeidentifier : Group To Remove : '0020' Action : 'delete
# 10:51:53, INFO DicomMetadataDeidentifier : Total : '8' Tags Found for Group  : '0020'
# 10:51:53, INFO DicomMetadataDeidentifier : Deleting Tag : '(0020,000D)' From Group : '0020' For VR : 'UI
# 10:51:53, INFO DicomMetadataDeidentifier : Deleting Tag : '(0020,000E)' From Group : '0020' For VR : 'UI
# ...

# %%
metadata_result_df[(metadata_result_df["Is_Changed"] == True) & (metadata_result_df["Is_Deleted"] == False)].head(20)
# Out:
#         Tag  VR Original_Value Cleaned_Value  Is_Changed  Is_Deleted
# 3  00080020  DA       20130713      20130812        True       False
# 4  00080021  DA       20130713      20130613        True       False
# 5  00080022  DA       20130713      20130723        True       False
# 6  00080023  DA       20130713      20130703        True       False

# %%
metadata_result_df[(metadata_result_df["Is_Changed"] == True) & (metadata_result_df["Is_Deleted"] == True)].head(20)
# Out:
#                      Tag  VR                                Original_Value  \
# 25              00090010  LO                                      FDMS 1.0
# 32              00130010  LO                                           CTP
# 54              00190010  LO                                      FDMS 1.0
# 55              0020000D  UI  2.25.106461954783291641048254423668956446198
# 56              0020000E  UI   2.25.22373700284337223907674770690654453238
# 57              00200010  SH
# 58              00200011  IS                                          1002
# 59              00200012  IS                                             3
# 60              00200013  IS                                          1002
# 61              00200020  CS
# 62              00200060  CS
# 63              00210010  LO                                      FDMS 1.0
# 64              00250010  LO                                      FDMS 1.0
# ...

# %% [markdown]
# ## Tags Marked for `cleanTag` Action
#
# In this section, we inspect all DICOM tags that are marked with the `cleanTag` action in the strategy file.
#
# These tags are **extracted as text** and passed through the **NER-based dPHI detection pipeline**, enabling contextual identification and de-identification of sensitive information present in metadata fields.

# %%
midib_root_path = './../data/dicom/midib/TCIA-MIDI-B-Synthetic-Test_20250502___1.2.714.0.0.7426654.9.695.1102170333010371365___1-1.dcm'

dicom_df = spark.read.format("binaryFile").load(midib_root_path)

dicom_df.columns
# Out:
# ['path', 'modificationTime', 'length', 'content']

# %% [markdown]
# ## Metadata NER DeIdentification Pipeline

# %%
def nlp_deidentification_pipeline(input_column="text"):

    t_document_assembler = DocumentAssembler() \
        .setInputCol(input_column) \
        .setOutputCol("t_document")

    t_sentencer = SentenceDetector()\
        .setInputCols(["t_document"])\
        .setOutputCol("t_sentence") \
        .setCustomBounds(["<dicom>"]) \
        .setUseCustomBoundsOnly(True)
    
    t_tokenizer = Tokenizer() \
        .setInputCols(["t_sentence"]) \
        .setOutputCol("t_token") \
        .setContextChars(["_", "^", "."])
    
    t_word_embeddings = WordEmbeddingsModel.pretrained("embeddings_clinical", "en", "clinical/models") \
        .setInputCols(["t_sentence", "t_token"]) \
        .setOutputCol("t_embeddings")
    
    t_ner_deidentify_dl = MedicalNerModel.pretrained("ner_deidentify_dl", "en", "clinical/models") \
        .setInputCols("t_sentence", "t_token", "t_embeddings") \
        .setOutputCol("t_ner_deidentify_dl")
    
    t_ner_deidentify_dl_ner_converter = NerConverterInternal() \
        .setInputCols(["t_sentence", "t_token", "t_ner_deidentify_dl"]) \
        .setOutputCol("t_ner_deidentify_dl_ner_chunk") \
        .setWhiteList(["DOCTOR", "PATIENT", "ORGANIZATION", "LOCATION-OTHER", "COUNTRY", "CITY", "STATE", "STREET", "ZIP"]) \
        .setThreshold(0.82)
    
    labels = ["CITY", "COUNTRY", "DATE", "DOCTOR", "HOSPITAL", "ORGANIZATION", "PATIENT", "PHONE", "PROFESSION", "STATE", "STREET", "ZIP"]
    t_zeroshot_ner_deid_subentity_docwise_large = PretrainedZeroShotNER().pretrained("zeroshot_ner_deid_subentity_docwise_large", "en", "clinical/models") \
        .setInputCols("t_sentence", "t_token") \
        .setOutputCol("t_zeroshot_ner_deid_subentity_docwise_large") \
        .setPredictionThreshold(0.90) \
        .setLabels(labels)
    
    t_zeroshot_ner_deid_subentity_docwise_large_ner_converter = NerConverterInternal()\
        .setInputCols("t_sentence", "t_token", "t_zeroshot_ner_deid_subentity_docwise_large")\
        .setOutputCol("t_zeroshot_ner_deid_subentity_docwise_large_ner_chunk")
    
    codes = [
        "AK","TSARH","BH","FGH","PH","WGMC","GVH","MCH","MJM","SS","CWASH","RASC","CMCH","FMCC",
        "TLM","RMABCH","EBMC","MM","SCH","WM","AAARM","HM","WHAYCC","BGH","NH","MDCH","DSAPCC",
        "MBARCH","CMC","MLASGH","FWARMC","GFASCC","JCH","MKAAH","WNGH","PAAHMC","WBARCC","HG",
        "WG","HMCC","CHC","HCCH","CHAJH","PQACH","MSCH","MJH","HMAJMC","DHCH","GGAMH","LGMC",
        "HRG","HGAWC","WJADC","DC","LCH","WSC","BJAHGH","SSABM","HSG","HHAMM","BGCC","JASGH",
        "HWGH","AMC","KM","RS","DL","CL","LS","KP","CV","AR","CB","SE","ES","JD","CCH","DBAMCH",
        "MSAMM","SBAJH","RTAJCC","BASM","VHG","HPCC","HPAOM","AL","RD","CW","DTAMG","SCASM",
        "HFACG","YPH","MWM","SL","SW","VAGH","SJ", "AH", "CH", "JCASCH", "LBAWCH","ECC", "NRALG",
        "MWG", "WBAACH", "FBH", "CAAFMC", "BYARMC"
    ]
    
    pattern = r"\b(" + "|".join(codes) + r")\b"
    
    t_regex_matcher = RegexMatcher() \
        .setInputCols("t_sentence") \
        .setOutputCol("t_regex") \
        .setRules([
            # Match known hospital or facility codes (from predefined list)
            pattern + ";CODES",
            # Match professional titles like Dr., DR., dr
            r"\b[Dd][Rr]\b\.?;PROFESSION",
            # Match numeric IDs in format: 123.456.7890x123
            r"\d{3}\.\d{3}\.\d{4}x\d{3};ID",
            # Match compact date-like numeric patterns (YYMMDD etc.)
            r"\b(?:\d{2}(0[1-9]|1[0-2])(0[1-9]|[12]\d|3[01]))\b;DATE",
            # Match phone-like pattern with parentheses and extension,
            # e.g. (151)265-4464x20 — but we tag it as DATE as per your request
            r"\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}(?:x\d{1,5})?;PHONE",
            # Match SSN-style numeric pattern (e.g. 300-45-3175) → labeled as DATE
            r"\b\d{3}-\d{2}-\d{4}\b;DATE"]) \
        .setDelimiter(";") 
    
    t_chunk_converter = ChunkConverter()\
        .setInputCols("t_regex")\
        .setOutputCol("t_regex_ner_chunk")
    
    t_chunk_merger = ChunkMergeApproach()\
        .setInputCols('t_regex_ner_chunk', 't_ner_deidentify_dl_ner_chunk', 't_zeroshot_ner_deid_subentity_docwise_large_ner_chunk')\
        .setOutputCol('t_merged_ner_chunk')\
        .setMergeOverlapping(True)
    
    filter_chunk = ["US", "MR BREAS", "MR BREAST BILAT", "MR BREASTUNI", "MIEDNICA", "WWO", "THINS", 
          "3D Rendering", "MAMMO", "CT", "DCE", "CA", "MC prostaat kliniek detectie-mc"]
    
    t_chunk_filterer = ChunkFilterer() \
      .setInputCols(["t_sentence","t_merged_ner_chunk"]) \
      .setOutputCol("t_filtered") \
      .setCriteria("isin") \
      .setFilterValue("result") \
      .setBlackList(filter_chunk)
    
    deid_obfuscated = DeIdentification() \
        .setInputCols(["t_sentence", "t_token", "t_filtered"]) \
        .setOutputCol("deid_documents") \
        .setMode("deid")

    nlp_pipeline = Pipeline(stages=[
        t_document_assembler,
        t_sentencer,
        t_tokenizer,
        t_word_embeddings,
        t_ner_deidentify_dl,
        t_ner_deidentify_dl_ner_converter,
        t_zeroshot_ner_deid_subentity_docwise_large,
        t_zeroshot_ner_deid_subentity_docwise_large_ner_converter,
        t_regex_matcher,
        t_chunk_converter,
        t_chunk_merger,
        t_chunk_filterer,
        deid_obfuscated
    ])

    empty_data = spark.createDataFrame([[""]]).toDF(input_column)
    nlp_model = nlp_pipeline.fit(empty_data)
    return nlp_model

# %%
csv_cleanTag_data = dedent("""\
    Tags,VR,Name,Status,Action,Option
    "(0008, 1030)",LO,Study Description,,cleanTag,remove,
    "(0018, 1030)",LO,Protocol Name,,cleanTag,deid,
    "(0040, 0310)",ST,Comments on Radiation Dose,,cleanTag,mask,
""")

# %%
dicom_to_metadata = DicomToMetadata() \
    .setInputCol("content") \
    .setOutputCol("metadata_original") \
    .setKeepInput(False) \
    .setExtractTagForNer(True) \
    .setTagMappingCol("tag_mapping") \
    .setTagCol("tag_text") \
    ._set(strategyFileContent=csv_cleanTag_data)

dicom_deidentifier = DicomMetadataDeidentifier() \
    .setInputCols(["path"]) \
    .setOutputCol("dicom_metadata_cleaned") \
    .setTagMappingCol("tag_mapping") \
    .setKeepInput(True) \
    .setTagCleanedCol("deid_documents") \
    ._set(strategyFileContent=csv_cleanTag_data)

extract_final_tag = DicomToMetadata() \
    .setInputCol("dicom_metadata_cleaned") \
    .setOutputCol("metadata_cleaned") \
    .setKeepInput(True) \
    .setExtractTagForNer(False)

pipeline = PipelineModel(stages=[
    dicom_to_metadata,
    nlp_deidentification_pipeline(input_column="tag_text"),
    dicom_deidentifier,
    extract_final_tag
])
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [ | ]embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# Download done! Loading the resource.
# [OK!]
# ner_deidentify_dl download started this may take some time.
# Approximate size to download 14.1 MB
# [ | ]ner_deidentify_dl download started this may take some time.
# Approximate size to download 14.1 MB
# [ / ]Download done! Loading the resource.
# [Stage 9:==================================>                       (9 + 1) / 15]
# [ — ]
# [OK!]
# zeroshot_ner_deid_subentity_docwise_large download started this may take some time.
# Approximate size to download 1.5 GB
# [ | ]zeroshot_ner_deid_subentity_docwise_large download started this may take some time.
# Approximate size to download 1.5 GB
# Download done! Loading the resource.
# [OK!]

# %%
result = pipeline.transform(dicom_df).cache()
result.columns
# Out:
# /usr/local/lib/python3.11/dist-packages/pyspark/sql/dataframe.py:169: UserWarning: DataFrame.sql_ctx is an internal property, and will be removed in future releases. Use DataFrame.sparkSession instead.
#   warnings.warn(
# ['exception',
#  'dicom_metadata_cleaned',
#  'path',
#  'metadata_original',
#  't_document',
#  't_sentence',
#  't_token',
#  't_embeddings',
#  't_ner_deidentify_dl',
#  't_ner_deidentify_dl_ner_chunk',
#  't_zeroshot_ner_deid_subentity_docwise_large',
#  't_zeroshot_ner_deid_subentity_docwise_large_ner_chunk',
#  't_regex',
#  't_regex_ner_chunk',
#  't_merged_ner_chunk',
#  't_filtered',
#  'external_mapping',
#  'metadata_cleaned']

# %%
metadata_result_df = build_metadata_comparison_df(dataframe=result, original_col="metadata_original", cleaned_col="metadata_cleaned")
metadata_result_df.head(5)
# Out:
# 10:52:54, INFO Run DicomToMetadata                                  (0 + 1) / 1]
# 10:52:54, INFO DicomToMetadata : Total Rules Extracted 3
# 10:52:54, INFO DicomToMetadata : Total cleanTag Action Found : 3
# 10:52:54, INFO DicomToMetadata : Returning Metadata, Document Object and Tag Mapping for NER
# Using CUDA
# 2026-08-03 10:53:01.869938046 [W:onnxruntime:, transformer_memcpy.cc:111 ApplyImpl] 81 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2026-08-03 10:53:01.891864186 [W:onnxruntime:, session_state.cc:1327 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# ...

# %%
metadata_result_df[(metadata_result_df["Is_Changed"] == True) & (metadata_result_df["Is_Deleted"] == False)].head(20)
# Out:
#          Tag  VR                        Original_Value  \
# 38  00181030  LO                    Performed 20120413
# 79  00400310  ST  Ordered for 298-34-0071 by Dr. Parks
#
#                             Cleaned_Value  Is_Changed  Is_Deleted
# 38                       Performed <DATE>        True       False
# 79  Ordered for **** by ********** ******        True       False

# %% [markdown]
# ## Extract UID/Patiend ID Mapping

# %%
from sparkocr.utils import generate_dicom_mapping

help(generate_dicom_mapping)
# Out:
# Help on function generate_dicom_mapping in module sparkocr.utils:
#
# generate_dicom_mapping(df, original_col, final_col)
#     Return mapping of old and new dicom identifiers.
#
#     :param df : Dataframe containing original and cleaned metadata
#     :param original_col : Dataframe column containing original metadata
#     :param final_col : Dataframe column containing cleaned metadata
#     :return {"uid_mapping" : {old_uid:new_uid}, "patient_mapping" : {old_patid:new_patid}

# %%
mapping_result = generate_dicom_mapping(result, "metadata_original", "metadata_cleaned")

columns = ["id_old", "id_new"]

uid_mapping = pd.DataFrame(list(mapping_result["uid_mapping"].items()), columns=columns)

uid_mapping.head(5)
# Out:
#                                           id_old  \
# 0                    1.2.840.10008.5.1.4.1.1.1.1
# 1  1.2.714.0.0.7426654.9.695.5152792103536035321
# 2  1.2.714.0.0.7426654.9.695.1530417802811153775
# 3  1.2.714.0.0.7426654.9.695.7173207380656716992
# 4  1.2.714.0.0.7426654.9.695.1102170333010371365
#
#                                           id_new
# 0                    1.2.840.10008.5.1.4.1.1.1.1
# 1  1.2.714.0.0.7426654.9.695.5152792103536035321
# 2  1.2.714.0.0.7426654.9.695.1530417802811153775
# 3  1.2.714.0.0.7426654.9.695.7173207380656716992
# 4  1.2.714.0.0.7426654.9.695.1102170333010371365

# %%
columns = ["id_old", "id_new"]

patient_mapping = pd.DataFrame(list(mapping_result["patient_mapping"].items()), columns=columns)

patient_mapping.head(20)
# Out:
#       id_old     id_new
# 0  913829086  913829086

# %% [markdown]
# ## Save Dicom File To Disk

# %%
root_path = "./dicom_deid_output"

os.makedirs(root_path, exist_ok=True)

for item in result.select("path", "dicom_metadata_cleaned").toLocalIterator():
    data = item.asDict()
    filename = os.path.basename(data["path"])

    file_out_path = os.path.join(root_path, filename)

    with open(file_out_path, "wb") as dicom_out:
        dicom_out.write(data["dicom_metadata_cleaned"])

# %%
shutil.rmtree(root_path)

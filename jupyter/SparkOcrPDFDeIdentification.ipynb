# %% [markdown]
# # Example of usage Spark OCR with Dicom Image Deidentifier

# %% [markdown]
# ## Install spark-ocr python packge
# Need specify:
# - license
# - path to `spark-ocr-assembly-[version].jar`
# - or `secret` for Spark OCR and `nlp_secret` for Spark NLP Internal
# - `aws_access_key` and `aws_secret_key`for download pretrained models

# %%
license = ""
secret = ""
nlp_secret = ""
aws_access_key = ""
aws_secret_key = ""

version = secret.split("-")[0]
spark_ocr_jar_path = "../../target/scala-2.12"

# %% [markdown]
# ## Initialization of spark session

# %%
from sparkocr import start

if license:
    os.environ['JSL_OCR_LICENSE'] = license
    os.environ['SPARK_NLP_LICENSE'] = license

if aws_access_key:
    os.environ['AWS_ACCESS_KEY'] = aws_access_key
    os.environ['AWS_SECRET_ACCESS_KEY'] = aws_secret_key

# if secret:
spark = start(secret=secret,
              jar_path=spark_ocr_jar_path)

spark
# Out:
# Spark version: 3.4.0
# Spark NLP version: 6.4.2-rc2
# Spark NLP for Healthcare version: 6.4.1
# Spark OCR version: 6.4.2
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.2:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark OCR</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Import Spark OCR transformers and Spark NLP annotators

# %%
import matplotlib.pyplot as plt

from sparknlp.annotator import *
from sparknlp.base import *
import sparknlp_jsl
from sparknlp_jsl.annotator import *

import sparkocr
from sparkocr.transformers import *
from sparkocr.enums import *
from sparkocr.utils import display_image, display_images_horizontal

print(f"Spark NLP version: {sparknlp.version()}")
print(f"Spark NLP internal version: {sparknlp_jsl.version()}")
print(f"Spark OCR version: {sparkocr.version()}")
# Out:
# Spark NLP version: 6.4.2-rc2
# Spark NLP internal version: 6.4.1
# Spark OCR version: 6.4.2

# %% [markdown]
# ## Define de-identification  NLP pipeline

# %%
def deidentification_nlp_pipeline(input_column, prefix = ""):
    document_assembler = DocumentAssembler() \
        .setInputCol(input_column) \
        .setOutputCol(prefix + "document")

    # Sentence Detector annotator, processes various sentences per line
    sentence_detector = SentenceDetector() \
        .setInputCols([prefix + "document"]) \
        .setOutputCol(prefix + "sentence")

    tokenizer = Tokenizer() \
        .setInputCols([prefix + "sentence"]) \
        .setOutputCol(prefix + "token")

    # Clinical word embeddings
    word_embeddings = WordEmbeddingsModel.pretrained() \
        .setInputCols([prefix + "sentence", prefix + "token"]) \
        .setOutputCol(prefix + "embeddings")
    # NER model trained on i2b2 (sampled from MIMIC) dataset
    clinical_ner = NerDLModel.pretrained() \
        .setInputCols([prefix + "sentence", prefix + "token", prefix + "embeddings"]) \
        .setOutputCol(prefix + "ner")

    custom_ner_converter = NerConverter() \
        .setInputCols([prefix + "sentence", prefix + "token", prefix + "ner"]) \
        .setOutputCol(prefix + "ner_chunk")

    nlp_pipeline = Pipeline(stages=[
            document_assembler,
            sentence_detector,
            tokenizer,
            word_embeddings,
            clinical_ner,
            custom_ner_converter
        ])
    empty_data = spark.createDataFrame([[""]]).toDF(input_column)
    nlp_model = nlp_pipeline.fit(empty_data)
    return nlp_model

# %% [markdown]
# ## Define OCR transformers and pipeline

# %%
# Convert to images
pdf_to_image = PdfToImage() \
    .setOutputCol("image_raw")

# Extract text from image
ocr = ImageToText() \
    .setInputCol("image_raw") \
    .setOutputCol("text") \
    .setIgnoreResolution(False) \
    .setPageIteratorLevel(PageIteratorLevel.SYMBOL) \
    .setPageSegMode(PageSegmentationMode.SPARSE_TEXT) \
    .setConfidenceThreshold(70)

# Found coordinates of sensitive data
position_finder = PositionFinder() \
    .setInputCols("ner_chunk") \
    .setOutputCol("coordinates") \
    .setPageMatrixCol("positions")

# Draw filled rectangle for hide sensitive data
drawRegions = ImageDrawRegions()  \
    .setInputCol("image_raw")  \
    .setInputRegionsCol("coordinates")  \
    .setOutputCol("image_with_regions")  \
    .setFilledRect(True) \
    .setRectColor(Color.gray)
    

# OCR pipeline
pipeline = Pipeline(stages=[
    pdf_to_image,
    ocr,
    deidentification_nlp_pipeline(input_column="text"),
    position_finder,
    drawRegions
])
# Out:
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# ner_dl download started this may take some time.
# Approximate size to download 13.6 MB
# [OK!]

# %% [markdown]
# ## Load image

# %%
import pkg_resources
pdf_path = "./pdfs/elon_musk.pdf"
image_df = spark.read.format("binaryFile").load(pdf_path)

# %%
image_df.show()
# Out:
# +--------------------+--------------------+------+--------------------+
# |                path|    modificationTime|length|             content|
# +--------------------+--------------------+------+--------------------+
# |file:/home/jose/s...|2023-06-16 15:26:...| 79038|[25 50 44 46 2D 3...|
# +--------------------+--------------------+------+--------------------+

# %% [markdown]
# ## Run pipeline

# %%
result = pipeline.fit(image_df).transform(image_df).cache()

# %% [markdown]
# ## Display chunks which need to hide

# %%
# NBVAL_SKIP
result.select('ner_chunk').show(2, False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |ner_chunk                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{chunk, 1, 19, Introduction\nSpaceX, {entity -> ORG, sentence -> 0, chunk -> 0}, []}, {chunk, 30, 71, Space Exploration Technologies Corporation, {entity -> ORG, sentence -> 0, chunk -> 1}, []}, {chunk, 74, 81, American, {entity -> MISC, sentence -> 0, chunk -> 2}, []}, {chunk, 335, 361, International Space\nStation, {entity -> ORG, sentence -> 1, chunk -> 3}, []}, {chunk, 364, 366, ISS, {entity -> ORG, sentence -> 1, chunk -> 4}, []}, {chunk, 390, 398, Hawthorne, {entity -> LOC, sentence -> 2, chunk -> 5}, []}, {chunk, 401, 410, California, {entity -> LOC, sentence -> 2, chunk -> 6}, []}, {chunk, 413, 418, SpaceX, {entity -> ORG, sentence -> 3, chunk -> 7}, []}, {chunk, 447, 455, Elon Musk, {entity -> ORG, sentence -> 3, chunk -> 8}, []}, {chunk, 596, 601, Falcon, {entity -> ORG, sentence -> 4, chunk -> 9}, []}, {chunk, 695, 700, Falcon, {entity -> ORG, sentence -> 5, chunk -> 10}, []}, {chunk, 870, 884, Lockheed Martin, {entity -> ORG, sentence -> 5, chunk -> 11}, []}, {chunk, 890, 895, Boeing, {entity -> ORG, sentence -> 5, chunk -> 12}, []}, {chunk, 963, 985, SpaceX-developed Merlin, {entity -> ORG, sentence -> 6, chunk -> 13}, []}, {chunk, 1051, 1056, SpaceX, {entity -> ORG, sentence -> 7, chunk -> 14}, []}]                            |
# |[{chunk, 1, 10, Tesla, Inc, {entity -> ORG, sentence -> 0, chunk -> 0}, []}, {chunk, 19, 26, American, {entity -> MISC, sentence -> 0, chunk -> 1}, []}, {chunk, 95, 100, Austin, {entity -> LOC, sentence -> 0, chunk -> 2}, []}, {chunk, 103, 107, Texas, {entity -> LOC, sentence -> 0, chunk -> 3}, []}, {chunk, 110, 114, Tesla, {entity -> ORG, sentence -> 1, chunk -> 4}, []}, {chunk, 315, 319, Tesla, {entity -> ORG, sentence -> 2, chunk -> 5}, []}, {chunk, 518, 529, Tesla Energy, {entity -> ORG, sentence -> 4, chunk -> 6}, []}, {chunk, 596, 608, United States, {entity -> LOC, sentence -> 4, chunk -> 7}, []}, {chunk, 611, 622, Tesla Energy, {entity -> ORG, sentence -> 5, chunk -> 8}, []}, {chunk, 747, 751, Tesla, {entity -> ORG, sentence -> 6, chunk -> 9}, []}, {chunk, 786, 800, Martin Eberhard, {entity -> PER, sentence -> 6, chunk -> 10}, []}, {chunk, 806, 820, Marc Tarpenning, {entity -> PER, sentence -> 6, chunk -> 11}, []}, {chunk, 825, 836, Tesla\nMotors, {entity -> ORG, sentence -> 6, chunk -> 12}, []}, {chunk, 907, 918, Nikola\nTesla, {entity -> PER, sentence -> 7, chunk -> 13}, []}, {chunk, 970, 978, Elon Musk, {entity -> ORG, sentence -> 8, chunk -> 14}, []}, {chunk, 1045, 1051, Tesla's, {entity -> ORG, sentence -> 10, chunk -> 15}, []}]|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Display coordinates of chunks which need to hide

# %%
# NBVAL_SKIP
result.select('coordinates').show(2, False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |coordinates                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{0, 0, 302.0, 317.85834, 453.9167, 41.616665, 0.0, Coordinate, 0.0, false}, {0, 0, 302.0, 429.73334, 157.5, 35.2, 0.0, Coordinate, 0.0, false}, {1, 0, 634.0, 430.17178, 977.9487, 32.32308, 0.0, Coordinate, 0.0, false}, {2, 0, 1642.0, 430.73126, 226.125, 30.6625, 0.0, Coordinate, 0.0, false}, {3, 0, 1692.0, 703.1972, 430.83325, 31.105556, 0.0, Coordinate, 0.0, false}, {3, 0, 302.0, 791.6143, 163.42857, 33.62857, 0.0, Coordinate, 0.0, false}, {4, 0, 492.0, 786.2167, 84.0, 39.233337, 0.0, Coordinate, 0.0, false}, {5, 0, 1067.0, 790.2167, 283.33334, 36.788887, 0.0, Coordinate, 0.0, false}, {6, 0, 1342.0, 789.06, 237.6, 36.08, 0.0, Coordinate, 0.0, false}, {7, 0, 302.0, 884.125, 175.0, 33.916668, 0.0, Coordinate, 0.0, false}, {8, 0, 1115.0, 880.1125, 264.375, 36.025, 0.0, Coordinate, 0.0, false}, {9, 0, 714.0, 1063.45, 179.66666, 34.100002, 0.0, Coordinate, 0.0, false}, {10, 0, 838.0, 1156.7167, 157.5, 31.900002, 0.0, Coordinate, 0.0, false}, {11, 0, 1178.0, 1335.85, 390.0, 34.728573, 0.0, Coordinate, 0.0, false}, {12, 0, 1664.0, 1336.7167, 158.66666, 35.566666, 0.0, Coordinate, 0.0, false}, {13, 0, 1455.0, 1428.3296, 577.09094, 33.75, 0.0, Coordinate, 0.0, false}, {14, 0, 1498.0, 1521.0, 175.0, 33.0, 0.0, Coordinate, 0.0, false}]                                                        |
# |[{0, 1, 301.0, 643.92773, 220.0, 35.811115, 0.0, Coordinate, 0.0, false}, {1, 1, 672.0, 644.7375, 229.5, 33.275, 0.0, Coordinate, 0.0, false}, {2, 1, 692.0, 710.3, 132.66669, 33.733334, 0.0, Coordinate, 0.0, false}, {3, 1, 860.0, 711.08997, 162.0, 33.22, 0.0, Coordinate, 0.0, false}, {4, 1, 1018.0, 710.87, 123.600006, 33.66, 0.0, Coordinate, 0.0, false}, {5, 1, 301.0, 927.98, 157.20001, 35.640003, 0.0, Coordinate, 0.0, false}, {6, 1, 607.0, 1150.0773, 285.0, 34.3, 0.0, Coordinate, 0.0, false}, {7, 1, 387.0, 1213.3708, 292.6667, 35.841667, 0.0, Coordinate, 0.0, false}, {8, 1, 712.0, 1216.05, 285.54547, 34.9, 0.0, Coordinate, 0.0, false}, {9, 1, 301.0, 1367.84, 122.399994, 34.32, 0.0, Coordinate, 0.0, false}, {10, 1, 1176.0, 1366.8286, 350.35718, 35.2, 0.0, Coordinate, 0.0, false}, {11, 1, 1646.0, 1368.8251, 375.0, 35.278576, 0.0, Coordinate, 0.0, false}, {12, 1, 2096.0, 1365.94, 152.4, 36.52, 0.0, Coordinate, 0.0, false}, {12, 1, 304.0, 1435.3417, 154.0, 32.81667, 0.0, Coordinate, 0.0, false}, {13, 1, 1984.0, 1431.6833, 126.5, 36.3, 0.0, Coordinate, 0.0, false}, {13, 1, 301.0, 1498.99, 150.0, 35.420002, 0.0, Coordinate, 0.0, false}, {14, 1, 1513.0, 1499.95, 232.75, 34.100002, 0.0, Coordinate, 0.0, false}, {15, 1, 1589.0, 1566.7856, 146.28572, 29.857143, 0.0, Coordinate, 0.0, false}]|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Show original and de-identified images

# %%
display_images_horizontal(result, "image_raw,image_with_regions")

# %%
result.unpersist(True)
# Out:
# +--------------------+--------------------+------+--------------------+-----------+-------+-----------+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+
# |                path|    modificationTime|length|           image_raw|total_pages|pagenum|documentnum|       confidence|                text|           positions|            document|            sentence|               token|          embeddings|                 ner|           ner_chunk|         coordinates|  image_with_regions|exception|
# +--------------------+--------------------+------+--------------------+-----------+-------+-----------+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+
# |file:/home/jose/s...|2023-06-16 15:26:...| 79038|{file:/home/jose/...|          2|      0|          0|99.50844574749168|\nIntroduction\nS...|[{[{I, 302.0, 314...|[{document, 0, 11...|[{document, 1, 17...|[{token, 1, 12, I...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1, 19, I...|[{0, 0, 302.0, 31...|{file:/home/jose/...|         |
# |file:/home/jose/s...|2023-06-16 15:26:...| 79038|{file:/home/jose/...|          2|      1|          0|99.51552070124232|\nTesla, Inc. is ...|[{[{T, 301.0, 640...|[{document, 0, 11...|[{document, 1, 10...|[{token, 1, 5, Te...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1, 10, T...|[{0, 1, 301.0, 64...|{file:/home/jose/...|         |
# +--------------------+--------------------+------+--------------------+-----------+-------+-----------+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+

# %% [markdown]
# # Example of extracting tables on selectable Pdfs

# %% [markdown]
# ## Install spark-ocr python packge
# Need specify path to `spark-ocr-assembly-[version].jar` or `secret`

# %%
secret = ""
license = ""
version = secret.split("-")[0]
spark_ocr_jar_path = "../../target/scala-2.12"

# %%
# %%bash
# if python -c 'import google.colab' &> /dev/null; then
#     echo "Run on Google Colab!"
#     echo "Install Open JDK"
#     apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
#     java -version
# fi

# %%
import os
import sys

if 'google.colab' in sys.modules:
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
  os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# %%
# install from PYPI using secret
#%pip install spark-ocr==$version+spark30 --extra-index-url=https://pypi.johnsnowlabs.com/$secret --upgrade
#%pip install --upgrade spark-ocr==4.0.0+spark32 --user --extra-index-url https://pypi.johnsnowlabs.com/$secret --upgrade

# %%
# or install from local path
# %pip install ../../python/dist/spark-ocr-1.9.0.tar.gz

# %% [markdown]
# ## Initialization of spark session

# %%
from sparkocr import start

if license:
    os.environ['JSL_OCR_LICENSE'] = license

spark = start(secret=secret, jar_path=spark_ocr_jar_path)
spark.conf.set("spark.sql.optimizer.expression.nestedPruning.enabled", False)
spark.conf.set("spark.sql.optimizer.nestedSchemaPruning.enabled", False)
spark
# Out:
# Spark version: 3.4.0
# Spark NLP version: 6.4.2-rc2
# Spark NLP for Healthcare version: 6.4.1
# Spark OCR version: 6.4.2
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.2:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark OCR</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Import OCR transformers

# %%
from sparkocr.transformers import *
from sparkocr.utils import display_image
from pyspark.sql.functions import collect_list,col

# %% [markdown]
# ## Read PDF document as binary file

# %%
import pkg_resources
pdf_example = pkg_resources.resource_filename('sparkocr', 'resources/ocr/pdfs/tabular-pdf/data.pdf')
pdf_example_df = spark.read.format("binaryFile").load(pdf_example).cache()

# %% [markdown]
# ## Display document

# %%
image_df = PdfToImage() \
    .setInputCol("content") \
    .setOutputCol("image") \
    .transform(pdf_example_df.select("content", "path"))
for r in image_df.limit(1).collect():
    display_image(r.image)
# Out:
#     Image #0:
#     Origin: file:/home/jose/.local/lib/python3.8/site-packages/sparkocr/resources/ocr/pdfs/tabular-pdf/data.pdf
#     Resolution: 300 dpi
#     Width: 2550 px
#     Height: 3299 px
#     Mode: ImageType.TYPE_BYTE_GRAY
#     Number of channels: 1
# <PIL.Image.Image image mode=L size=2550x3299>

# %% [markdown]
# ## Extract table from PDF document per page

# %%
pdf_to_text_table = PdfToTextTable()
pdf_to_text_table.setInputCol("content")
pdf_to_text_table.setOutputCol("table")
pdf_to_text_table.setPageIndex(1)
pdf_to_text_table.setMethod("basic")

table = pdf_to_text_table.transform(pdf_example_df)

# %% [markdown]
# ## Show first row

# %%
table.select(table["table.chunks"].getItem(1)["chunkText"]).show(1, False)
# Out:
# +------------------------------------------------------------------+
# |table.chunks AS chunks#186[1].chunkText                           |
# +------------------------------------------------------------------+
# |[Mazda RX4, 21.0, 6, , 160.0, 110, 3.90, 2.620, 16.46, 0, 1, 4, 4]|
# +------------------------------------------------------------------+

# %% [markdown]
# ## Display first element in first row

# %%
table.select(table["table.chunks"].getItem(1)["chunkText"][0]).show()
# Out:
# +------------------------------------------+
# |table.chunks AS chunks#274[1].chunkText[0]|
# +------------------------------------------+
# |                                 Mazda RX4|
# +------------------------------------------+

# %% [markdown]
# ## Display first element in first row with coordinates

# %%
table.select(table["table.chunks"].getItem(1)[0]).show(1, False)
# Out:
# +-------------------------------------------+
# |table.chunks AS chunks[1][0]               |
# +-------------------------------------------+
# |{Mazda RX4, 154.69, 141.5, 53.806473, 4.42}|
# +-------------------------------------------+

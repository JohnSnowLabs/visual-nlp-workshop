# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/visual-nlp-workshop/blob/master/jupyter/SparkOcrStoreResultsToPdfWithTextLayout.ipynb)

# %% [markdown]
# # Example of usage Spark OCR for recognize text from Image PDF and store results to PDF with text layout

# %% [markdown]
# ## Install spark-ocr python packge
# Need specify path to `spark-ocr-assembly-[version].jar` or `secret`

# %%
secret = ""
license = ""
version = secret.split("-")[0]
spark_ocr_jar_path = "../../target/scala-2.12"

# %%
# %%bash
# if python -c 'import google.colab' &> /dev/null; then
#     echo "Run on Google Colab!"
#     echo "Install Open JDK"
#     apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
#     java -version
# fi

# %%
import sys
import os

if 'google.colab' in sys.modules:
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
  os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# %%
# install from PYPI using secret
# %pip install spark-ocr==$version+spark30 --extra-index-url=https://pypi.johnsnowlabs.com/$secret --upgrade

# %%
# or install from local path
# %pip install --user ../../python/dist/spark-ocr-1.9.0.spark24.tar.gz

# %% [markdown]
# ## Initialization of spark session

# %%
from pyspark.sql import SparkSession
from sparkocr import start

if license:
    os.environ['JSL_OCR_LICENSE'] = license

spark = start(secret=secret, jar_path=spark_ocr_jar_path)
spark
# Out:
# Spark version: 3.4.0
# Spark NLP version: 6.4.2-rc2
# Spark NLP for Healthcare version: 6.4.1
# Spark OCR version: 6.4.2
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.2:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark OCR</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Import OCR transformers

# %%
from sparkocr.transformers import *
from sparkocr.enums import *
from pyspark.ml import PipelineModel
from sparkocr.utils import display_image

# %% [markdown]
# ## Define OCR transformers and pipeline

# %%
def pipeline():
    # Transforrm PDF document to images per page
    pdf_to_image = PdfToImage() \
        .setInputCol("content") \
        .setOutputCol("image") \
        .setKeepInput(True)
    
    # Run OCR
    ocr = ImageToText() \
        .setInputCol("image") \
        .setOutputCol("text") \
        .setConfidenceThreshold(60) \
        .setIgnoreResolution(False) \
        .setPageSegMode(PageSegmentationMode.SPARSE_TEXT)
    
    # Render results to PDF
    textToPdf = TextToPdf() \
        .setInputCol("positions") \
        .setInputImage("image") \
        .setOutputCol("pdf")

    pipeline = PipelineModel(stages=[
        pdf_to_image,
        ocr,
        textToPdf
    ])
    
    return pipeline

# %% [markdown]
# ## Read PDF document as binary file

# %%
import pkg_resources
pdf_example = pkg_resources.resource_filename('sparkocr', 'resources/ocr/pdfs/test_document.pdf')
pdf_example_df = spark.read.format("binaryFile").load(pdf_example).cache()

# %% [markdown]
# ## Run OCR pipelines

# %%
result = pipeline().transform(pdf_example_df).cache()

# %% [markdown]
# ## Store results to pdf file

# %%
pdf = result.select("pdf").head().pdf
pdfFile = open("result.pdf", "wb")
pdfFile.write(pdf)
pdfFile.close()

# %% [markdown]
# ## Convert pdf to image and display

# %%
image_df = PdfToImage() \
    .setInputCol("pdf") \
    .setOutputCol("image") \
    .transform(result.select("pdf", "path"))
for r in image_df.collect():
    display_image(r.image)
# Out:
#     Image #0:
#     Origin: file:/home/jose/.local/lib/python3.8/site-packages/sparkocr/resources/ocr/pdfs/test_document.pdf
#     Resolution: 300 dpi
#     Width: 5333 px
#     Height: 7333 px
#     Mode: ImageType.TYPE_BYTE_GRAY
#     Number of channels: 1
# <PIL.Image.Image image mode=L size=5333x7333>
#     Image #0:
#     Origin: file:/home/jose/.local/lib/python3.8/site-packages/sparkocr/resources/ocr/pdfs/test_document.pdf
#     Resolution: 300 dpi
#     Width: 5333 px
#     Height: 6999 px
#     Mode: ImageType.TYPE_BYTE_GRAY
#     Number of channels: 1
# <PIL.Image.Image image mode=L size=5333x6999>

# %%
result.unpersist()
# Out:
# +--------------------+--------------------+--------------------+---------+
# |                path|                text|                 pdf|exception|
# +--------------------+--------------------+--------------------+---------+
# |file:/home/jose/....|[Patient Nam\n\nF...|[25 50 44 46 2D 3...|         |
# +--------------------+--------------------+--------------------+---------+

# %%
# %%bash
# rm -r -f result.pdf

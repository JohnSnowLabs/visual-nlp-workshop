# %% [markdown]
# # Form Recognition in Spark Ocr
#
# End-to-end form recognition using VisualDocumentNerV2 and FormRelationExtractor.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/visual-nlp-workshop/blob/master/tutorials/Certification_Trainings/03.01.Spark_OCR_Form_Recognition.ipynb)

# %% [markdown]
# If you are using the `johnsnowlabs` library, please use this [03.01.Spark_OCR_Form_Recognition](https://github.com/JohnSnowLabs/visual-nlp-workshop/blob/master/tutorials/Certification_Trainings_JSL/03.01.Spark_OCR_Form_Recognition.ipynb) notebook.

# %% [markdown]
# ## Blogposts and videos
#
# - [Text Detection in Spark OCR](https://medium.com/spark-nlp/text-detection-in-spark-ocr-dcd8002bdc97)
#
# - [Table Detection & Extraction in Spark OCR](https://medium.com/spark-nlp/table-detection-extraction-in-spark-ocr-50765c6cedc9)
#
# - [Extract Tabular Data from PDF in Spark OCR](https://medium.com/spark-nlp/extract-tabular-data-from-pdf-in-spark-ocr-b02136bc0fcb)
#
# - [Signature Detection in Spark OCR](https://medium.com/spark-nlp/signature-detection-in-spark-ocr-32f9e6f91e3c)
#
# - [GPU image pre-processing in Spark OCR](https://medium.com/spark-nlp/gpu-image-pre-processing-in-spark-ocr-3-1-0-6fc27560a9bb)
#
# - [How to Setup Spark OCR on UBUNTU - Video](https://www.youtube.com/watch?v=cmt4WIcL0nI)
#
#
# **More examples here**
#
# https://github.com/JohnSnowLabs/spark-ocr-workshop

# %% [markdown]
# ### Colab Setup

# %%
# NBVAL_SKIP
import json, os
import sys

if 'google.colab' in sys.modules:
    from google.colab import files

    if 'spark_ocr.json' not in os.listdir():
      license_keys = files.upload()
      os.rename(list(license_keys.keys())[0], 'spark_ocr.json')

with open('spark_ocr.json') as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)

# %%
# NBVAL_SKIP
# Installing pyspark and spark-nlp
# %pip install --upgrade -q pyspark==3.4.1 spark-nlp==$PUBLIC_VERSION

# Installing Spark OCR
#! pip uninstall spark-ocr -Y
# %pip install spark-ocr==$OCR_VERSION --extra-index-url=https://pypi.johnsnowlabs.com/$SPARK_OCR_SECRET --upgrade

# %% [markdown]
# <b><h1><font color='darkred'>!!! ATTENTION !!! </font><h1><b>
#
# <b>Running the next cell will <font color='darkred'>automatically restart the Colab runtime</font>. This is expected — once it restarts, just continue running the cells below.<b>

# %%
import os
os.kill(os.getpid(), 9)

# %%
# NBVAL_SKIP
import json, os

with open("spark_ocr.json", 'r') as f:
  license_keys = json.load(f)

# Adding license key-value pairs to environment variables
os.environ.update(license_keys)

# Defining license key-value pairs as local variables
locals().update(license_keys)

# %%
from pyspark.ml import PipelineModel
import pyspark.sql.functions as f

# %%
import importlib.resources

from pyspark.ml import PipelineModel
from pyspark.sql import functions as F

from sparkocr import start
from sparkocr.transformers import *
from sparkocr.enums import *
from sparkocr.utils import *
from sparkocr.metrics import score

# %% [markdown]
# ## Start spark session

# %%
# Start spark
spark = start(secret=SPARK_OCR_SECRET)
# Out:
# Spark version: 3.4.1
# Spark NLP version: 6.4.0
# Spark OCR version: 6.4.0

# %% [markdown]
# ## Load image

# %%
import importlib.resources
test_image_path = str(importlib.resources.files('sparkocr') / 'resources/ocr/forms/form1.jpg')
bin_df = spark.read.format("binaryFile").load(test_image_path)
display_images(BinaryToImage().transform(bin_df))
# Out:
#     Image #0:
#     Origin: file:/usr/local/lib/python3.12/dist-packages/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 150 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: 10
#     Number of channels: 1
# <PIL.Image.Image image mode=L size=1240x1755>

# %% [markdown]
# ## Define pipeline

# %%
binary_to_image = BinaryToImage()\
    .setOutputCol("image") \
    .setImageType(ImageType.TYPE_3BYTE_BGR)

img_to_hocr = ImageToHocr()\
    .setInputCol("image")\
    .setOutputCol("hocr")\
    .setIgnoreResolution(False)\
    .setOcrParams(["preserve_interword_spaces=0"])

tokenizer = HocrTokenizer()\
    .setInputCol("hocr")\
    .setOutputCol("tokens")

doc_ner = VisualDocumentNer()\
    .pretrained("lilt_roberta_funsd_v1", "en", "clinical/ocr")\
    .setInputCols(["tokens", "image"])\
    .setOutputCol("entities")

rel_extractor = FormRelationExtractor() \
    .setInputCol("entities") \
    .setOutputCol("relations")

# .setRectColor(Color.red) removed: spark-ocr 6.4.0 raises
# AttributeError on this setter even though it's still documented;
# falls back to the default black outline.
draw_key_values = ImageDrawAnnotations() \
    .setInputCol("image") \
    .setInputChunksCol("relations") \
    .setOutputCol("image_with_annotations") \
    .setFontSize(10) \
    .setLineWidth(4)

draw_ner = ImageDrawAnnotations() \
    .setInputCol("image") \
    .setInputChunksCol("entities") \
    .setOutputCol("image_with_ner") \
    .setFontSize(10) \
    .setLineWidth(4)

# OCR pipeline
pipeline = PipelineModel(stages=[
    binary_to_image,
    img_to_hocr,
    tokenizer,
    doc_ner,
    rel_extractor,
    draw_key_values,
    draw_ner
])
# Out:
# lilt_roberta_funsd_v1 download started this may take some time.
# Approximate size to download 419.6 MB

# %% [markdown]
# ## Call pipeline

# %%
results = pipeline.transform(bin_df).cache()
results.select(f.explode("entities")).show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# |col                                                                                                                                                    |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{named_entity, 0, 7, b-question, {x -> 1027, y -> 89, height -> 19, confidence -> 106, token -> version, ocr_confidence -> 96, width -> 90}, []}       |
# |{named_entity, 7, 8, i-question, {x -> 1027, y -> 89, height -> 19, confidence -> 67, token -> :, ocr_confidence -> 96, width -> 90}, []}              |
# |{named_entity, 10, 15, b-question, {x -> 1020, y -> 128, height -> 23, confidence -> 95, token -> study, ocr_confidence -> 96, width -> 61}, []}       |
# |{named_entity, 15, 17, b-question, {x -> 1088, y -> 128, height -> 19, confidence -> 77, token -> id, ocr_confidence -> 96, width -> 29}, []}          |
# |{named_entity, 17, 18, i-question, {x -> 1088, y -> 128, height -> 19, confidence -> 41, token -> :, ocr_confidence -> 96, width -> 29}, []}           |
# |{named_entity, 20, 31, b-question, {x -> 407, y -> 190, height -> 37, confidence -> 86, token -> institution, ocr_confidence -> 96, width -> 241}, []} |
# |{named_entity, 31, 35, i-question, {x -> 667, y -> 190, height -> 37, confidence -> 45, token -> name, ocr_confidence -> 96, width -> 130}, []}        |
# |{named_entity, 35, 46, b-question, {x -> 498, y -> 276, height -> 19, confidence -> 102, token -> institution, ocr_confidence -> 96, width -> 113}, []}|
# |{named_entity, 46, 53, b-question, {x -> 618, y -> 276, height -> 19, confidence -> 67, token -> address, ocr_confidence -> 96, width -> 89}, []}      |
# |{named_entity, 53, 64, b-question, {x -> 454, y -> 339, height -> 19, confidence -> 103, token -> institution, ocr_confidence -> 96, width -> 114}, []}|
# |{named_entity, 64, 71, b-question, {x -> 575, y -> 339, height -> 19, confidence -> 82, token -> address, ocr_confidence -> 96, width -> 90}, []}      |
# |{named_entity, 71, 75, b-question, {x -> 673, y -> 339, height -> 19, confidence -> 98, token -> line, ocr_confidence -> 96, width -> 43}, []}         |
# |{named_entity, 75, 76, i-question, {x -> 724, y -> 339, height -> 19, confidence -> 72, token -> #, ocr_confidence -> 96, width -> 24}, []}            |
# |{named_entity, 76, 77, i-question, {x -> 724, y -> 339, height -> 19, confidence -> 65, token -> 2, ocr_confidence -> 96, width -> 24}, []}            |
# |{named_entity, 77, 86, b-question, {x -> 497, y -> 402, height -> 23, confidence -> 88, token -> telephone, ocr_confidence -> 93, width -> 117}, []}   |
# |{named_entity, 86, 87, b-question, {x -> 622, y -> 402, height -> 19, confidence -> 64, token -> &, ocr_confidence -> 93, width -> 14}, []}            |
# |{named_entity, 87, 92, b-question, {x -> 645, y -> 402, height -> 19, confidence -> 88, token -> email, ocr_confidence -> 96, width -> 60}, []}        |
# |{named_entity, 92, 96, b-question, {x -> 58, y -> 478, height -> 19, confidence -> 108, token -> name, ocr_confidence -> 92, width -> 69}, []}         |
# |{named_entity, 96, 97, i-question, {x -> 58, y -> 478, height -> 19, confidence -> 84, token -> :, ocr_confidence -> 92, width -> 69}, []}             |
# |{named_entity, 97, 101, b-answer, {x -> 143, y -> 478, height -> 22, confidence -> 108, token -> dribbler, ocr_confidence -> 91, width -> 92}, []}     |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Show results

# %%
results.select("exception").show(truncate=False)
# Out:
# +---------+
# |exception|
# +---------+
# |null     |
# +---------+

# %%
results.select(f.explode("relations.result")).show(20, False)
# Out:
# +--------------------------------------------+
# |col                                         |
# +--------------------------------------------+
# |name : dribbler , bbb                       |
# |study date : 12 - 09 - 2006 , 6 : 34        |
# |bp : 120 / 80 mmhg                          |
# |mrn : 12341820060912                        |
# |patient location : room1                    |
# |hr : 100 bpm                                |
# |dob : 19 - 06 - 1979                        |
# |gender : male                               |
# |height : 123 cm                             |
# |age : 27 years                              |
# |weight : 25 kg                              |
# |reason for study : mi                       |
# |bsa : 0 . 92 m2                             |
# |history : asfgfdgsdg                        |
# |medications : heparine , paracetamol        |
# |performed .: the study technically limited .|
# |.: no                                       |
# +--------------------------------------------+

# %%
results.withColumn("metadata", f.explode("relations.metadata")) \
 .select(f.col("metadata.entity1").alias("key"), f.col("metadata.entity2").alias("value")).show(20, False)
# Out:
# +------------------+-------------------------------+
# |key               |value                          |
# +------------------+-------------------------------+
# |name :            |dribbler , bbb                 |
# |study date :      |12 - 09 - 2006 , 6 : 34        |
# |bp :              |120 / 80 mmhg                  |
# |mrn :             |12341820060912                 |
# |patient location :|room1                          |
# |hr :              |100 bpm                        |
# |dob :             |19 - 06 - 1979                 |
# |gender :          |male                           |
# |height :          |123 cm                         |
# |age :             |27 years                       |
# |weight :          |25 kg                          |
# |reason for study :|mi                             |
# |bsa :             |0 . 92 m2                      |
# |history :         |asfgfdgsdg                     |
# |medications :     |heparine , paracetamol         |
# |performed .       |the study technically limited .|
# |.                 |no                             |
# +------------------+-------------------------------+

# %% [markdown]
# ### Show NER results

# %%
display_images(results, "image_with_ner")
# Out:
#     Image #0:
#     Origin: file:/usr/local/lib/python3.12/dist-packages/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 0 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: 5
#     Number of channels: 3
# <PIL.Image.Image image mode=RGB size=1240x1755>

# %% [markdown]
# ### Show final annotations

# %%
display_images(results, "image_with_annotations")
# Out:
#     Image #0:
#     Origin: file:/usr/local/lib/python3.12/dist-packages/sparkocr/resources/ocr/forms/form1.jpg
#     Resolution: 0 dpi
#     Width: 1240 px
#     Height: 1755 px
#     Mode: 5
#     Number of channels: 3
# <PIL.Image.Image image mode=RGB size=1240x1755>
